# %% [markdown]
# <h1 style="text-align:center">
#     Estadísticas de Accidentes en Madrid
# </h1>
#
# <br>
#
# <font color="darkblue">
#
# <h3 style="text-align:center">
#     Óscar David Vásquez Peraza
# </h3>
#
# <h3 style="text-align:center">
#     25/04/2022
# </h3>
#
# <hr>

# %% [markdown]
# ## Introducción
#
# <font color="darkblue"> En este proyecto se desarrolla en Python un análisis básico de datos sobre accidentes de tráfico de la Comunidad de Madrid. Los datos provienen de ***.
# A partir de ellos he realizado ... He conseguido ... pero no he podido ...
# </font>
#
# <font color="green">Completa tú el breve apartado anterior. Elimina este párrafo en verde. A partir de ahora, pon en azul los comentarios tuyos, dejando en negro los míos, del enunciado.
# </font>
#
# ## Librerías
#
# <font color="darkblue">
# Pongamos todas las librerías necesarias al principio, tal como propone el estilo `pep-8`. Ej.:
# <a href="https://www.python.org/dev/peps/pep-0008/">PEP 8 -- Style Guide for Python Code</a>.
# </font>

# %%
import csv
import itertools
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## a) Algunas operaciones sencillas [2 puntos]
#
# Vamos a trabajar con una tabla del INE que contiene información sobre el paro en España. Abriendo el archivo, vemos algo así:
#
# <center>
#     <img src="./images/tabla_1.png" width="800">
# </center>
#
# Si miramos una línea de esta tabla (salvo la primera, que es la cabecera), encontamos lo siguiente:
#
# <table>
#   <tr>
#     <th>2020S000073</th>
#     <th>01/01/2020</th>
#     <th>18:48</th>
#     <th>AVDA. PIO XII</th>
#     <th>81</th>
#     <th>CHAMARTÍN</th>
#     <th>Atropello a persona</th>
#     <th>Despejado</th>
#     <th>Turismo</th>
#     <th>Conductor</th>
#     <th>DE 55 A 59 AÑOS</th>
#     <th>Hombre</th>
#     <th>14</th>
#     <th> </th>
#   </tr>
# </table>
#
# Pero si inspeccionamos el archivo con un editor de texto, vemos que esa línea es como sigue:
#
#     2020S000073;01/01/2020;18:48;AVDA. PIO XII;81;CHAMARTÍN;Atropello a persona;Despejado;Turismo;Conductor;DE 55 A 59 AÑOS;Hombre;14;;
#
# Una cadena de caracteres. Hagamos en Python algunas operaciones básicas con los algunos de los datos anteriores y con la cadena en sí.

# %% [markdown]
# **a.1 Redondeo de la hora**
#
# La primera operación consiste en redondear una hora, simplemente despreciando los minutos y dando lugar al entero correspondiente, entre 0 y 23.

# %%
# Esta celda debe ser completada por el estudiante
def redondeo_hora(cadena: str):
    return int(cadena.split(':')[0])

# %%
# Pruebas de funcionamiento:

print(redondeo_hora('12:48'))
# Out:
# 12

# %% [markdown]
# Es bastante habitual hacer varias pruebas a la vez:

# %%
# Pruebas de funcionamiento:

for h in ['15:00', '23:15', '14:22', '9:34']:
    print(redondeo_hora(h))
# Out:
# 15
# 23
# 14
# 9

# %% [markdown]
# **a.2 Rangos de edad**
#
# Ahora, deseamos codificar los rangos de edad, asignando a cada rango descrito un intervalo de dos enteros. El ejemplo de funcionamiento te aclarará lo que se pide exactamente:

# %%
# Esta celda debe ser completada por el estudiante
def rango_edad(cadena: str):
    datos = cadena.split(' ')
    return tuple((-1,-1)) if len(datos) < 2 else \
           ( tuple((int(datos[1]),int(datos[3]))) if len(datos) > 4 \
           else tuple((int(datos[2])+1,100)) )

# %%
# Pruebas de funcionamiento:

for c in  ['DE 25 A 29 AÑOS', 'DESCONOCIDA', 'MAYOR DE 74 AÑOS']:
    print(c, " -> ", rango_edad(c))
# Out:
# DE 25 A 29 AÑOS  ->  (25, 29)
# DESCONOCIDA  ->  (-1, -1)
# MAYOR DE 74 AÑOS  ->  (75, 100)

# %% [markdown]
# **a.3 Lesividad: datos en blanco**
#
# El dato de lesividad viene codificado con un entero:
#
#     01 Atención en urgencias sin posterior ingreso. - LEVE
#     02 Ingreso inferior o igual a 24 horas - LEVE
#     ...
#     77 Se desconoce
#     En blanco Sin asistencia sanitaria
#
# Deseamos convertir este dato en un número entero. Cuando no se requiere asistencia sanitaria vamos a codificar esto con el entero 0 por homogeneidad. Cuando la lesividad no se conoce (un dato missing por ejemplo), también la consignaremos con un cero.

# %%
# Esta celda debe ser completada por el estudiante
def lesividad(cadena: str):
    return int(cadena) if cadena else 0

# %%
# Pruebas de funcionamiento:

for c in  ['01', '02', '14', '', '77']:
    print(c, " -> ", lesividad(c))
# Out:
# 01  ->  1
# 02  ->  2
# 14  ->  14
#   ->  0
# 77  ->  77

# %% [markdown]
# **a.4 Operaciones con una línea de datos**
#
# Si ahora abres el archivo de datos con un editor de texto, podrás ver algo parecido a lo siguiente:
#
# <center>
#     <img src="./images/tabla_2.png" width="800">
# </center>
#
# La línea novena es la que poníamos antes como ejemplo. Vista como una cadena de caracteres, podemos almacenarla en una variable para procesarla:
#
#
#     linea_9 = "2020S000073;01/01/2020;18:48;AVDA. PIO XII;81;CHAMARTÍN;Atropello a persona;Despejado;Turismo;Conductor;DE 55 A 59 AÑOS;Hombre;14;;"
#
# Y luego, podríamos hacer con ella algunas operaciones básicas, separando sus piezas (con el método `split`), extrayendo alguna que nos interese (accediendo a la componente adecuada con el corchete `[...]`, y estas piezas se pueden manejar con las funciones definicas antes, `redondeo_hora` y `rango_edad`.
#
# En una primera versión, esto puede hacerse con una función que va imprimiendo las cosas, así:
#
#     def presentar_operaciones_basicas(cadena):
#         print("La cadena de entrada: ")
#         print(cadena)
#         print()
#         print("Piezas: ")
#         ...

# %%
# Esta celda debe ser completada por el estudiante
def presentar_operaciones_basicas(cadena: str):
    print("La cadena de entrada: ")
    print(cadena, end="\n\n")
    
    print("Piezas: ")
    lista = cadena.split(';')
    print(lista, end="\n\n")

    print("Distrito: ")
    print(lista[5], end="\n\n")

    print("La hora, sin y con redondeo: ")
    print(lista[2])
    print(redondeo_hora(lista[2]), end="\n\n")

    print("La edad, tal como viene y en  su rango: ")
    print(lista[10])
    print(rango_edad(lista[10]))

# %%
# Ejemplo de funcionamiento:

linea_9 = "2020S000073;01/01/2020;18:48;AVDA. PIO XII;81;CHAMARTÍN;Atropello a persona;Despejado;Turismo;Conductor;DE 55 A 59 AÑOS;Hombre;14;;"
presentar_operaciones_basicas(linea_9)
# Out:
# La cadena de entrada:
# 2020S000073;01/01/2020;18:48;AVDA. PIO XII;81;CHAMARTÍN;Atropello a persona;Despejado;Turismo;Conductor;DE 55 A 59 AÑOS;Hombre;14;;
#
# Piezas:
# ['2020S000073', '01/01/2020', '18:48', 'AVDA. PIO XII', '81', 'CHAMARTÍN', 'Atropello a persona', 'Despejado', 'Turismo', 'Conductor', 'DE 55 A 59 AÑOS', 'Hombre', '14', '', '']
#
# Distrito:
# CHAMARTÍN
#
# La hora, sin y con redondeo:
# 18:48
# 18
#
# La edad, tal como viene y en  su rango:
# DE 55 A 59 AÑOS
# (55, 59)

# %% [markdown]
# Decíamos que, en una primera versión, esto puede hacerse con una función que va imprimiendo las cosas.
# Pero realmente, no es el estilo deseable. Preferimos una función que no escriba nada, que devuelva su resultado con `return`. Y de paso, que devuelva únicamente las piezas que nos interesan, por ejemplo: la hora (redondeada), el distrito, el estado meteorológico, el rango de edad y el nivel (entero) de lesividad del accidente.
#
# (Lógicamente, según el objetivo que nos interese, podría ser necesario luego cargar unos campos u otros.)

# %%
# Esta celda debe ser completada por el estudiante
def extraer_datos(cadena: str):
    lista = cadena.split(';')
    return [redondeo_hora(lista[2]),lista[5],lista[7],\
            rango_edad(lista[10]),lesividad(lista[12])]

# %%
# Pruebas de funcionamiento:

print(len(linea_9.split(";")))
print(extraer_datos(linea_9))
# Out:
# 15
# [18, 'CHAMARTÍN', 'Despejado', (55, 59), 14]

# %% [markdown]
# ## b) Lectura de datos del archivo [2 puntos]
#
# En este apartado te planteo diseñar tres funciones de lectura de datos.
#
# **b.1. Cabecera** La primera función leerá la cabecera del archivo de datos, esto es, su primera línea, y la descompondrá en los rótulos correspondientes a cada columna. Además de abrir el archivo (preferiblemente con la instrucción `with open...`), bastará con un único `readline`.

# %%
# Esta celda debe ser completada por el estudiante
def cargar_cabecera(fichero: str):
    with open(fichero, encoding='iso-8859-1', newline='') as archivo:
        cabecera = archivo.readline().strip()
    return cabecera.split(sep=';')

# %%
# Pruebas de funcionamiento:

cabecera = cargar_cabecera("2020_Accidentalidad.csv")
print(cabecera)
# Out:
# ['Nº  EXPEDIENTE', 'FECHA', 'HORA', 'CALLE', 'NÚMERO', 'DISTRITO', 'TIPO ACCIDENTE', 'ESTADO METEREOLÓGICO', 'TIPO VEHÍCULO', 'TIPO PERSONA', 'RANGO DE EDAD', 'SEXO', 'LESIVIDAD*', '', '']

# %% [markdown]
# **b.2 Lectura de algunas líneas del archivo**
#
# Ahora, nos interesa leer justamente los datos a partir de la cabecera, esto es algunas de las demás líneas. Una forma de saltarnos esa primera línea es usar la instrucción `next`. Pongamos que queremos leer desde la línea $17$ hasta la $23$. Podemos leer (sin procesar) $17-1$ líneas y luego, podemos leer y retener $23-17+1$ líneas.

# %%
# Esta celda debe ser completada por el estudiante
def cargar_lineas(fichero: str, inicio=1, fin=10):

    with open(fichero, encoding='iso-8859-1', newline='') as archivo:
        accidentalidad = csv.DictReader(archivo,delimiter=';')
        
        lista = [ [
                redondeo_hora(fila['HORA']), \
                fila['DISTRITO'], \
                fila['ESTADO METEREOLÓGICO'], \
                rango_edad(fila['RANGO DE EDAD']), \
                lesividad(fila['LESIVIDAD*'])] \
                for fila in itertools.islice(accidentalidad, inicio-1, fin)]

        return lista

# %%
lineas_lista = cargar_lineas("2020_Accidentalidad.csv", 1, 4)

for linea in lineas_lista:
    print(linea)
    
# Si no decimos qué líneas nos interesa, se cargarán las diez primeras.
# (Esto puede hacerse con dos parámetros por defecto.)

print()

lineas_lista = cargar_lineas("2020_Accidentalidad.csv")

for linea in lineas_lista:
    print(linea)
# Out:
# [23, 'RETIRO', 'Despejado', (25, 29), 0]
# [22, 'MONCLOA-ARAVACA', 'Despejado', (21, 24), 6]
# [20, 'FUENCARRAL-EL PARDO', 'Despejado', (45, 49), 14]
# [20, 'FUENCARRAL-EL PARDO', 'Despejado', (25, 29), 7]
#
# [23, 'RETIRO', 'Despejado', (25, 29), 0]
# [22, 'MONCLOA-ARAVACA', 'Despejado', (21, 24), 6]
# [20, 'FUENCARRAL-EL PARDO', 'Despejado', (45, 49), 14]
# [20, 'FUENCARRAL-EL PARDO', 'Despejado', (25, 29), 7]
# [19, 'CENTRO', 'Despejado', (-1, -1), 0]
# [19, 'CARABANCHEL', 'Despejado', (-1, -1), 14]
# [19, 'CARABANCHEL', 'Despejado', (21, 24), 2]
# [18, 'CHAMARTÍN', 'Despejado', (55, 59), 14]
# [18, 'CHAMARTÍN', 'Despejado', (18, 20), 7]
# [18, 'ARGANZUELA', '', (55, 59), 14]

# %% [markdown]
# **b.3 Lectura de todas las líneas del archivo**
#
# Lo normal es desear cargar **todos** los datos de un archivo, y no sólo unas pocas líneas, excluyendo la cabecera. Al igual que en la función anterior, te pido que el resultado se dé en una lista, donde cada elemento recoge la información de una línea del archivo de datos, salvo la cabecera, pero incluyendo ahora **todas** esas líneas, sin dar opción a cuáles nos interesa, aunque luego deseemos mostrar tan solo unas pocas. Véanse ambas pruebas de funcionamiento.

# %%
# Esta celda debe ser completada por el estudiante
def cargar_datos(fichero: str):
    with open(fichero,'rb') as file:
        total_filas = len(file.readlines())
    return cargar_lineas("2020_Accidentalidad.csv",1, total_filas)

# %%
# Pruebas de funcionamiento:

datos_lista = cargar_datos("2020_Accidentalidad.csv")

for linea in datos_lista:
    print(linea)
# Out:
# [23, 'RETIRO', 'Despejado', (25, 29), 0]
# [22, 'MONCLOA-ARAVACA', 'Despejado', (21, 24), 6]
# [20, 'FUENCARRAL-EL PARDO', 'Despejado', (45, 49), 14]
# [20, 'FUENCARRAL-EL PARDO', 'Despejado', (25, 29), 7]
# [19, 'CENTRO', 'Despejado', (-1, -1), 0]
# [19, 'CARABANCHEL', 'Despejado', (-1, -1), 14]
# [19, 'CARABANCHEL', 'Despejado', (21, 24), 2]
# [18, 'CHAMARTÍN', 'Despejado', (55, 59), 14]
# [18, 'CHAMARTÍN', 'Despejado', (18, 20), 7]
# [18, 'ARGANZUELA', '', (55, 59), 14]
# [18, 'ARGANZUELA', '', (35, 39), 14]
# [16, 'HORTALEZA', 'Despejado', (40, 44), 0]
# [16, 'HORTALEZA', 'Despejado', (30, 34), 0]
# [16, 'HORTALEZA', 'Despejado', (-1, -1), 0]
# [16, 'PUENTE DE VALLECAS', 'Despejado', (45, 49), 14]
# [16, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 2]
# [16, 'PUENTE DE VALLECAS', 'Despejado', (40, 44), 2]
# [16, 'PUENTE DE VALLECAS', 'Despejado', (45, 49), 2]
# [15, 'HORTALEZA', 'Despejado', (21, 24), 14]
# [15, 'HORTALEZA', 'Despejado', (18, 20), 0]
# [15, 'HORTALEZA', 'Despejado', (-1, -1), 0]
# [15, 'HORTALEZA', 'Despejado', (-1, -1), 0]
# [15, 'HORTALEZA', 'Despejado', (-1, -1), 0]
# [15, 'CARABANCHEL', 'Despejado', (50, 54), 6]
# [15, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [15, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [15, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [15, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [15, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [14, 'PUENTE DE VALLECAS', 'Despejado', (55, 59), 0]
# [14, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [14, 'HORTALEZA', 'Despejado', (35, 39), 1]
# [14, 'PUENTE DE VALLECAS', 'Despejado', (40, 44), 14]
# [14, 'PUENTE DE VALLECAS', 'Despejado', (50, 54), 1]
# [14, 'PUENTE DE VALLECAS', 'Despejado', (30, 34), 14]
# [14, 'PUENTE DE VALLECAS', 'Despejado', (60, 64), 14]
# [14, 'PUENTE DE VALLECAS', 'Despejado', (45, 49), 14]
# [14, 'PUENTE DE VALLECAS', 'Despejado', (45, 49), 14]
# [14, 'SAN BLAS-CANILLEJAS', 'Despejado', (45, 49), 0]
# [14, 'SAN BLAS-CANILLEJAS', 'Despejado', (45, 49), 0]
# [14, 'SAN BLAS-CANILLEJAS', 'Despejado', (-1, -1), 0]
# [14, 'SAN BLAS-CANILLEJAS', 'Despejado', (-1, -1), 0]
# [14, 'SAN BLAS-CANILLEJAS', 'Despejado', (-1, -1), 0]
# [13, 'PUENTE DE VALLECAS', '', (40, 44), 0]
# [12, 'LATINA', 'Despejado', (18, 20), 14]
# [12, 'RETIRO', 'Despejado', (65, 69), 7]
# [12, 'RETIRO', 'Despejado', (35, 39), 7]
# [12, 'FUENCARRAL-EL PARDO', 'Despejado', (45, 49), 0]
# [12, 'FUENCARRAL-EL PARDO', 'Despejado', (18, 20), 0]
# [12, 'FUENCARRAL-EL PARDO', 'Despejado', (15, 17), 0]
# [10, 'CIUDAD LINEAL', 'Despejado', (-1, -1), 14]
# [10, 'CIUDAD LINEAL', 'Despejado', (55, 59), 14]
# [10, 'RETIRO', '', (40, 44), 14]
# [10, 'RETIRO', '', (21, 24), 14]
# [9, 'FUENCARRAL-EL PARDO', 'Despejado', (-1, -1), 0]
# [9, 'FUENCARRAL-EL PARDO', 'Despejado', (35, 39), 14]
# [9, 'FUENCARRAL-EL PARDO', 'Despejado', (30, 34), 7]
# [9, 'FUENCARRAL-EL PARDO', 'Despejado', (25, 29), 14]
# [9, 'PUENTE DE VALLECAS', 'Despejado', (18, 20), 14]
# [9, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [9, 'CARABANCHEL', 'Despejado', (25, 29), 7]
# [9, 'CARABANCHEL', 'Despejado', (25, 29), 14]
# [9, 'CARABANCHEL', 'Despejado', (25, 29), 14]
# [8, 'SAN BLAS-CANILLEJAS', 'Despejado', (30, 34), 0]
# [7, 'CENTRO', 'Despejado', (45, 49), 0]
# [7, 'CENTRO', 'Despejado', (30, 34), 0]
# [7, 'SALAMANCA', 'Despejado', (25, 29), 0]
# [7, 'SALAMANCA', 'Despejado', (40, 44), 0]
# [7, 'SALAMANCA', 'Despejado', (55, 59), 0]
# [7, 'SALAMANCA', 'Despejado', (18, 20), 0]
# [6, 'RETIRO', 'Despejado', (35, 39), 0]
# [6, 'RETIRO', 'Despejado', (-1, -1), 0]
# [6, 'LATINA', 'Despejado', (25, 29), 7]
# [6, 'SALAMANCA', 'Despejado', (25, 29), 14]
# [6, 'SALAMANCA', 'Despejado', (25, 29), 14]
# [6, 'SALAMANCA', 'Despejado', (40, 44), 3]
# [5, 'CARABANCHEL', 'Despejado', (25, 29), 0]
# [5, 'CARABANCHEL', 'Despejado', (18, 20), 0]
# [5, 'CARABANCHEL', 'Despejado', (35, 39), 0]
# [5, 'CARABANCHEL', 'Despejado', (45, 49), 14]
# [3, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 14]
# [3, 'CENTRO', 'Despejado', (35, 39), 0]
# [3, 'CENTRO', 'Despejado', (-1, -1), 0]
# [2, 'CHAMBERÍ', 'Despejado', (70, 74), 0]
# [2, 'CHAMBERÍ', 'Despejado', (40, 44), 0]
# [2, 'CHAMBERÍ', 'Despejado', (40, 44), 0]
# [2, 'CHAMARTÍN', 'Despejado', (35, 39), 14]
# [2, 'CHAMARTÍN', 'Despejado', (35, 39), 14]
# [2, 'CHAMARTÍN', 'Despejado', (55, 59), 14]
# [2, 'CHAMARTÍN', 'Despejado', (25, 29), 14]
# [1, 'USERA', 'Despejado', (35, 39), 14]
# [1, 'USERA', 'Despejado', (21, 24), 14]
# [1, 'HORTALEZA', 'Despejado', (21, 24), 0]
# [1, 'HORTALEZA', 'Despejado', (40, 44), 0]
# [1, 'SAN BLAS-CANILLEJAS', '', (30, 34), 0]
# [1, 'SAN BLAS-CANILLEJAS', '', (18, 20), 0]
# [1, 'CIUDAD LINEAL', 'Despejado', (30, 34), 0]
# [1, 'CIUDAD LINEAL', 'Despejado', (-1, -1), 0]
# [1, 'CIUDAD LINEAL', 'Despejado', (-1, -1), 0]
# [1, 'RETIRO', 'Despejado', (40, 44), 0]
# [1, 'RETIRO', 'Despejado', (18, 20), 0]
# [23, 'CHAMARTÍN', 'Despejado', (40, 44), 0]
# [23, 'CHAMARTÍN', 'Despejado', (40, 44), 0]
# [23, 'CHAMARTÍN', 'Despejado', (25, 29), 0]
# [23, 'USERA', 'Despejado', (65, 69), 14]
# [23, 'USERA', 'Despejado', (60, 64), 14]
# [23, 'USERA', 'Despejado', (25, 29), 2]
# [23, 'USERA', 'Despejado', (21, 24), 2]
# [23, 'USERA', 'Despejado', (25, 29), 2]
# [22, 'TETUÁN', '', (40, 44), 0]
# [22, 'TETUÁN', '', (21, 24), 0]
# [22, 'RETIRO', 'Despejado', (25, 29), 7]
# [22, 'RETIRO', 'Despejado', (25, 29), 14]
# [22, 'RETIRO', 'Despejado', (55, 59), 7]
# [20, 'CARABANCHEL', 'Despejado', (35, 39), 7]
# [20, 'CARABANCHEL', 'Despejado', (70, 74), 2]
# [20, 'CARABANCHEL', 'Despejado', (50, 54), 14]
# [20, 'CARABANCHEL', 'Despejado', (70, 74), 14]
# [20, 'CHAMARTÍN', 'Despejado', (75, 100), 14]
# [20, 'CHAMARTÍN', 'Despejado', (70, 74), 14]
# [20, 'CHAMARTÍN', 'Despejado', (35, 39), 14]
# [20, 'FUENCARRAL-EL PARDO', '', (50, 54), 0]
# [20, 'FUENCARRAL-EL PARDO', '', (50, 54), 0]
# [19, 'CARABANCHEL', 'Despejado', (25, 29), 14]
# [19, 'CARABANCHEL', 'Despejado', (0, 5), 2]
# [19, 'HORTALEZA', 'Despejado', (25, 29), 4]
# [19, 'HORTALEZA', 'Despejado', (75, 100), 14]
# [19, 'HORTALEZA', 'Despejado', (-1, -1), 0]
# [19, 'HORTALEZA', 'Despejado', (-1, -1), 0]
# [19, 'LATINA', 'Se desconoce', (50, 54), 14]
# [19, 'LATINA', 'Se desconoce', (65, 69), 7]
# [18, 'FUENCARRAL-EL PARDO', 'Despejado', (50, 54), 14]
# [18, 'FUENCARRAL-EL PARDO', 'Despejado', (55, 59), 2]
# [18, 'CENTRO', '', (25, 29), 0]
# [18, 'CENTRO', '', (-1, -1), 0]
# [17, 'CARABANCHEL', 'Despejado', (40, 44), 0]
# [17, 'CARABANCHEL', 'Despejado', (30, 34), 14]
# [17, 'CARABANCHEL', 'Despejado', (40, 44), 0]
# [17, 'CARABANCHEL', 'Despejado', (30, 34), 0]
# [17, 'CARABANCHEL', 'Despejado', (60, 64), 0]
# [17, 'SAN BLAS-CANILLEJAS', 'Despejado', (65, 69), 14]
# [17, 'SAN BLAS-CANILLEJAS', 'Despejado', (60, 64), 14]
# [17, 'SAN BLAS-CANILLEJAS', 'Despejado', (25, 29), 7]
# [17, 'ARGANZUELA', 'Despejado', (45, 49), 14]
# [17, 'ARGANZUELA', 'Despejado', (40, 44), 1]
# [17, 'ARGANZUELA', 'Despejado', (35, 39), 14]
# [17, 'PUENTE DE VALLECAS', 'Lluvia débil', (18, 20), 0]
# [17, 'PUENTE DE VALLECAS', 'Lluvia débil', (45, 49), 0]
# [17, 'SALAMANCA', 'Despejado', (45, 49), 0]
# [17, 'SALAMANCA', 'Despejado', (-1, -1), 0]
# [17, 'SALAMANCA', 'Despejado', (-1, -1), 0]
# [16, 'TETUÁN', 'Despejado', (50, 54), 14]
# [16, 'TETUÁN', 'Despejado', (18, 20), 0]
# [16, 'TETUÁN', 'Despejado', (35, 39), 14]
# [16, 'TETUÁN', 'Despejado', (35, 39), 14]
# [16, 'ARGANZUELA', 'Despejado', (30, 34), 14]
# [16, 'ARGANZUELA', 'Despejado', (25, 29), 3]
# [16, 'ARGANZUELA', 'Despejado', (-1, -1), 0]
# [16, 'ARGANZUELA', 'Despejado', (-1, -1), 0]
# [15, 'SALAMANCA', 'Despejado', (25, 29), 14]
# [15, 'SALAMANCA', 'Despejado', (25, 29), 14]
# [15, 'SALAMANCA', 'Despejado', (75, 100), 14]
# [15, 'SALAMANCA', 'Despejado', (70, 74), 14]
# [14, 'RETIRO', 'Despejado', (30, 34), 6]
# [14, 'RETIRO', 'Despejado', (50, 54), 14]
# [14, 'MONCLOA-ARAVACA', 'Despejado', (45, 49), 0]
# [14, 'MONCLOA-ARAVACA', 'Despejado', (75, 100), 0]
# [14, 'MONCLOA-ARAVACA', 'Despejado', (35, 39), 0]
# [14, 'MONCLOA-ARAVACA', 'Despejado', (55, 59), 0]
# [14, 'FUENCARRAL-EL PARDO', 'Despejado', (-1, -1), 0]
# [14, 'FUENCARRAL-EL PARDO', 'Despejado', (55, 59), 0]
# [13, 'HORTALEZA', 'Despejado', (50, 54), 0]
# [13, 'HORTALEZA', 'Despejado', (35, 39), 0]
# [13, 'BARAJAS', 'Despejado', (45, 49), 0]
# [13, 'BARAJAS', 'Despejado', (-1, -1), 0]
# [13, 'BARAJAS', 'Despejado', (-1, -1), 0]
# [13, 'VILLA DE VALLECAS', 'Despejado', (35, 39), 0]
# [13, 'VILLA DE VALLECAS', 'Despejado', (-1, -1), 0]
# [13, 'VILLA DE VALLECAS', 'Despejado', (55, 59), 0]
# [12, 'CENTRO', 'Despejado', (35, 39), 1]
# [12, 'CENTRO', 'Despejado', (50, 54), 14]
# [12, 'CENTRO', 'Despejado', (45, 49), 14]
# [12, 'SAN BLAS-CANILLEJAS', 'Despejado', (30, 34), 7]
# [12, 'SAN BLAS-CANILLEJAS', 'Despejado', (55, 59), 14]
# [12, 'SAN BLAS-CANILLEJAS', 'Despejado', (30, 34), 14]
# [12, 'SAN BLAS-CANILLEJAS', 'Despejado', (25, 29), 7]
# [12, 'VICÁLVARO', 'Despejado', (60, 64), 0]
# [12, 'MONCLOA-ARAVACA', 'Despejado', (45, 49), 7]
# [12, 'MONCLOA-ARAVACA', 'Despejado', (35, 39), 14]
# [12, 'ARGANZUELA', 'Despejado', (40, 44), 0]
# [12, 'ARGANZUELA', 'Despejado', (45, 49), 0]
# [12, 'BARAJAS', 'Despejado', (35, 39), 0]
# [12, 'BARAJAS', 'Despejado', (45, 49), 0]
# [11, 'MORATALAZ', 'Despejado', (30, 34), 14]
# [11, 'MORATALAZ', 'Despejado', (50, 54), 14]
# [10, 'SAN BLAS-CANILLEJAS', 'Despejado', (25, 29), 14]
# [10, 'SAN BLAS-CANILLEJAS', 'Despejado', (40, 44), 14]
# [10, 'SAN BLAS-CANILLEJAS', 'Despejado', (45, 49), 7]
# [10, 'ARGANZUELA', 'Despejado', (40, 44), 0]
# [10, 'ARGANZUELA', 'Despejado', (25, 29), 0]
# [10, 'USERA', 'Se desconoce', (50, 54), 0]
# [10, 'USERA', 'Se desconoce', (50, 54), 0]
# [10, 'USERA', 'Se desconoce', (15, 17), 0]
# [10, 'PUENTE DE VALLECAS', 'Despejado', (50, 54), 14]
# [10, 'PUENTE DE VALLECAS', 'Despejado', (45, 49), 6]
# [8, 'VILLAVERDE', 'Despejado', (60, 64), 0]
# [8, 'VILLAVERDE', 'Despejado', (50, 54), 0]
# [8, 'ARGANZUELA', 'Despejado', (30, 34), 14]
# [8, 'PUENTE DE VALLECAS', 'Despejado', (30, 34), 0]
# [7, 'HORTALEZA', 'Despejado', (50, 54), 14]
# [7, 'HORTALEZA', 'Despejado', (50, 54), 2]
# [7, 'SAN BLAS-CANILLEJAS', 'Despejado', (25, 29), 14]
# [7, 'SAN BLAS-CANILLEJAS', 'Despejado', (40, 44), 7]
# [7, 'CIUDAD LINEAL', 'Despejado', (18, 20), 14]
# [7, 'CIUDAD LINEAL', 'Despejado', (21, 24), 14]
# [6, 'ARGANZUELA', 'Despejado', (50, 54), 14]
# [6, 'ARGANZUELA', 'Despejado', (55, 59), 14]
# [6, 'ARGANZUELA', 'Despejado', (40, 44), 7]
# [5, 'ARGANZUELA', 'Despejado', (-1, -1), 14]
# [5, 'ARGANZUELA', 'Despejado', (21, 24), 14]
# [5, 'ARGANZUELA', 'Despejado', (21, 24), 14]
# [5, 'ARGANZUELA', 'Despejado', (25, 29), 14]
# [5, 'ARGANZUELA', 'Despejado', (30, 34), 14]
# [5, 'PUENTE DE VALLECAS', 'Despejado', (25, 29), 7]
# [5, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 7]
# [5, 'PUENTE DE VALLECAS', 'Despejado', (60, 64), 2]
# [5, 'PUENTE DE VALLECAS', 'Despejado', (21, 24), 2]
# [5, 'MORATALAZ', 'Despejado', (-1, -1), 0]
# [5, 'MORATALAZ', 'Despejado', (-1, -1), 0]
# [5, 'MORATALAZ', 'Despejado', (-1, -1), 0]
# [2, 'USERA', 'Despejado', (40, 44), 0]
# [2, 'USERA', 'Despejado', (18, 20), 0]
# [2, 'USERA', 'Despejado', (18, 20), 0]
# [2, 'VILLA DE VALLECAS', 'Despejado', (25, 29), 0]
# [2, 'VILLA DE VALLECAS', 'Despejado', (-1, -1), 0]
# [2, 'VILLA DE VALLECAS', 'Despejado', (-1, -1), 0]
# [0, 'MORATALAZ', 'Despejado', (45, 49), 0]
# [0, 'MORATALAZ', 'Despejado', (35, 39), 0]
# [23, 'VILLAVERDE', 'Se desconoce', (50, 54), 0]
# [23, 'VILLAVERDE', 'Se desconoce', (30, 34), 0]
# [23, 'SAN BLAS-CANILLEJAS', 'Despejado', (30, 34), 14]
# [23, 'SAN BLAS-CANILLEJAS', 'Despejado', (21, 24), 7]
# [22, 'MONCLOA-ARAVACA', 'Despejado', (60, 64), 14]
# [22, 'MONCLOA-ARAVACA', 'Despejado', (45, 49), 14]
# [22, 'MONCLOA-ARAVACA', 'Despejado', (50, 54), 6]
# [22, 'MONCLOA-ARAVACA', 'Despejado', (6, 9), 6]
# [22, 'VICÁLVARO', 'Despejado', (55, 59), 14]
# [22, 'VICÁLVARO', 'Despejado', (30, 34), 7]
# [22, 'VICÁLVARO', 'Despejado', (6, 9), 7]
# [22, 'VICÁLVARO', 'Despejado', (0, 5), 14]
# [22, 'VICÁLVARO', 'Despejado', (21, 24), 14]
# [22, 'VICÁLVARO', 'Despejado', (21, 24), 14]
# [22, 'VILLAVERDE', 'Despejado', (25, 29), 0]
# [22, 'PUENTE DE VALLECAS', 'Despejado', (25, 29), 0]
# [22, 'PUENTE DE VALLECAS', 'Despejado', (55, 59), 0]
# [22, 'HORTALEZA', 'Se desconoce', (55, 59), 0]
# [22, 'HORTALEZA', 'Se desconoce', (50, 54), 0]
# [21, 'USERA', 'Despejado', (21, 24), 14]
# [21, 'RETIRO', 'Despejado', (50, 54), 0]
# [21, 'RETIRO', 'Despejado', (40, 44), 0]
# [20, 'SALAMANCA', 'Despejado', (45, 49), 7]
# [20, 'SALAMANCA', 'Despejado', (25, 29), 14]
# [19, 'RETIRO', 'Despejado', (21, 24), 0]
# [19, 'RETIRO', 'Despejado', (40, 44), 0]
# [19, 'RETIRO', 'Despejado', (-1, -1), 0]
# [19, 'RETIRO', 'Despejado', (50, 54), 0]
# [19, 'RETIRO', 'Despejado', (50, 54), 0]
# [19, 'CIUDAD LINEAL', 'Despejado', (30, 34), 14]
# [19, 'CIUDAD LINEAL', 'Despejado', (50, 54), 14]
# [19, 'CIUDAD LINEAL', 'Despejado', (50, 54), 14]
# [19, 'CIUDAD LINEAL', 'Despejado', (30, 34), 14]
# [19, 'CIUDAD LINEAL', 'Despejado', (55, 59), 14]
# [19, 'CIUDAD LINEAL', 'Despejado', (-1, -1), 0]
# [18, 'PUENTE DE VALLECAS', 'Despejado', (55, 59), 0]
# [18, 'PUENTE DE VALLECAS', 'Despejado', (25, 29), 0]
# [17, 'BARAJAS', 'Nublado', (60, 64), 0]
# [17, 'BARAJAS', 'Nublado', (18, 20), 0]
# [17, 'ARGANZUELA', 'Despejado', (50, 54), 14]
# [17, 'ARGANZUELA', 'Despejado', (0, 5), 7]
# [17, 'SAN BLAS-CANILLEJAS', 'Despejado', (25, 29), 14]
# [17, 'SAN BLAS-CANILLEJAS', 'Despejado', (30, 34), 7]
# [17, 'MONCLOA-ARAVACA', 'Despejado', (21, 24), 0]
# [17, 'MONCLOA-ARAVACA', 'Despejado', (25, 29), 0]
# [17, 'HORTALEZA', 'Despejado', (35, 39), 0]
# [17, 'HORTALEZA', 'Despejado', (25, 29), 0]
# [16, 'CHAMBERÍ', 'Despejado', (21, 24), 6]
# [16, 'CHAMBERÍ', 'Despejado', (35, 39), 14]
# [16, 'CARABANCHEL', 'Despejado', (30, 34), 0]
# [16, 'CARABANCHEL', 'Despejado', (70, 74), 0]
# [15, 'FUENCARRAL-EL PARDO', 'Despejado', (60, 64), 0]
# [15, 'FUENCARRAL-EL PARDO', 'Despejado', (21, 24), 0]
# [15, 'CARABANCHEL', 'Despejado', (35, 39), 14]
# [15, 'CARABANCHEL', 'Despejado', (40, 44), 7]
# [15, 'CHAMARTÍN', 'Despejado', (25, 29), 5]
# [15, 'CIUDAD LINEAL', 'Despejado', (60, 64), 14]
# [15, 'CIUDAD LINEAL', 'Despejado', (50, 54), 14]
# [15, 'CIUDAD LINEAL', 'Despejado', (50, 54), 14]
# [15, 'CARABANCHEL', 'Despejado', (45, 49), 14]
# [15, 'CARABANCHEL', 'Despejado', (60, 64), 6]
# [15, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 0]
# [15, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 0]
# [14, 'FUENCARRAL-EL PARDO', 'Despejado', (25, 29), 14]
# [14, 'FUENCARRAL-EL PARDO', 'Despejado', (40, 44), 14]
# [14, 'VICÁLVARO', 'Despejado', (25, 29), 0]
# [14, 'CHAMBERÍ', '', (35, 39), 0]
# [14, 'CHAMBERÍ', '', (40, 44), 0]
# [14, 'CHAMBERÍ', 'Despejado', (25, 29), 7]
# [14, 'CHAMBERÍ', 'Despejado', (45, 49), 14]
# [14, 'CHAMBERÍ', '', (55, 59), 0]
# [14, 'CHAMBERÍ', '', (21, 24), 0]
# [13, 'BARAJAS', 'Nublado', (60, 64), 3]
# [13, 'BARAJAS', 'Nublado', (40, 44), 77]
# [12, 'SAN BLAS-CANILLEJAS', 'Nublado', (45, 49), 0]
# [12, 'SAN BLAS-CANILLEJAS', 'Nublado', (30, 34), 0]
# [12, 'SAN BLAS-CANILLEJAS', 'Nublado', (55, 59), 0]
# [12, 'PUENTE DE VALLECAS', 'Despejado', (65, 69), 0]
# [12, 'PUENTE DE VALLECAS', 'Despejado', (25, 29), 0]
# [12, 'PUENTE DE VALLECAS', 'Despejado', (30, 34), 0]
# [12, 'PUENTE DE VALLECAS', 'Despejado', (30, 34), 0]
# [11, 'HORTALEZA', 'Despejado', (55, 59), 0]
# [11, 'HORTALEZA', 'Despejado', (-1, -1), 0]
# [11, 'HORTALEZA', 'Despejado', (-1, -1), 0]
# [11, 'PUENTE DE VALLECAS', 'Despejado', (25, 29), 7]
# [11, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 14]
# [6, 'MORATALAZ', 'Despejado', (55, 59), 2]
# [6, 'MORATALAZ', 'Despejado', (50, 54), 2]
# [6, 'VILLA DE VALLECAS', 'Despejado', (35, 39), 14]
# [6, 'VILLA DE VALLECAS', 'Despejado', (-1, -1), 2]
# [0, 'SALAMANCA', 'Despejado', (60, 64), 0]
# [23, 'CHAMBERÍ', 'Despejado', (21, 24), 7]
# [23, 'CHAMBERÍ', 'Despejado', (40, 44), 14]
# [22, 'USERA', 'Despejado', (25, 29), 7]
# [22, 'USERA', 'Despejado', (45, 49), 14]
# [22, 'LATINA', 'Se desconoce', (40, 44), 14]
# [22, 'LATINA', 'Se desconoce', (55, 59), 14]
# [22, 'LATINA', 'Se desconoce', (55, 59), 14]
# [21, 'CENTRO', 'Despejado', (25, 29), 14]
# [21, 'CENTRO', 'Despejado', (18, 20), 14]
# [21, 'CENTRO', 'Despejado', (30, 34), 6]
# [21, 'CARABANCHEL', 'Despejado', (65, 69), 14]
# [21, 'CARABANCHEL', 'Despejado', (75, 100), 6]
# [21, 'CARABANCHEL', 'Despejado', (40, 44), 14]
# [21, 'CARABANCHEL', 'Despejado', (50, 54), 14]
# [21, 'FUENCARRAL-EL PARDO', 'Despejado', (40, 44), 7]
# [21, 'FUENCARRAL-EL PARDO', 'Despejado', (25, 29), 7]
# [20, 'VILLA DE VALLECAS', 'Despejado', (55, 59), 0]
# [20, 'VILLA DE VALLECAS', 'Despejado', (65, 69), 0]
# [20, 'VILLA DE VALLECAS', 'Despejado', (55, 59), 7]
# [20, 'VILLA DE VALLECAS', 'Despejado', (-1, -1), 0]
# [19, 'CIUDAD LINEAL', 'Despejado', (35, 39), 0]
# [19, 'CIUDAD LINEAL', 'Despejado', (-1, -1), 0]
# [18, 'USERA', 'Despejado', (55, 59), 7]
# [18, 'USERA', 'Despejado', (40, 44), 14]
# [17, 'FUENCARRAL-EL PARDO', 'Despejado', (50, 54), 14]
# [17, 'FUENCARRAL-EL PARDO', 'Despejado', (50, 54), 1]
# [17, 'FUENCARRAL-EL PARDO', 'Despejado', (45, 49), 14]
# [17, 'CIUDAD LINEAL', 'Despejado', (35, 39), 0]
# [16, 'LATINA', 'Se desconoce', (40, 44), 14]
# [16, 'LATINA', 'Se desconoce', (21, 24), 6]
# [15, 'CIUDAD LINEAL', 'Despejado', (18, 20), 14]
# [15, 'CIUDAD LINEAL', 'Despejado', (30, 34), 5]
# [14, 'TETUÁN', 'Despejado', (75, 100), 14]
# [14, 'TETUÁN', 'Despejado', (75, 100), 2]
# [14, 'TETUÁN', 'Despejado', (75, 100), 2]
# [14, 'CHAMBERÍ', 'Despejado', (30, 34), 1]
# [14, 'CHAMBERÍ', 'Despejado', (30, 34), 2]
# [14, 'VILLA DE VALLECAS', 'Despejado', (55, 59), 7]
# [14, 'VILLA DE VALLECAS', 'Despejado', (30, 34), 7]
# [13, 'CENTRO', 'Despejado', (55, 59), 7]
# [13, 'CENTRO', 'Despejado', (-1, -1), 0]
# [13, 'PUENTE DE VALLECAS', 'Despejado', (45, 49), 0]
# [13, 'PUENTE DE VALLECAS', 'Despejado', (25, 29), 0]
# [13, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [13, 'TETUÁN', 'Despejado', (40, 44), 14]
# [13, 'TETUÁN', 'Despejado', (21, 24), 7]
# [13, 'FUENCARRAL-EL PARDO', 'Despejado', (35, 39), 6]
# [13, 'RETIRO', 'Despejado', (35, 39), 14]
# [13, 'RETIRO', 'Despejado', (65, 69), 7]
# [13, 'RETIRO', 'Despejado', (45, 49), 14]
# [13, 'SAN BLAS-CANILLEJAS', '', (40, 44), 0]
# [13, 'SAN BLAS-CANILLEJAS', '', (45, 49), 0]
# [13, 'RETIRO', 'Despejado', (50, 54), 1]
# [12, 'TETUÁN', 'Despejado', (40, 44), 0]
# [12, 'TETUÁN', 'Despejado', (-1, -1), 0]
# [12, 'CARABANCHEL', 'Despejado', (70, 74), 0]
# [12, 'FUENCARRAL-EL PARDO', 'Despejado', (40, 44), 2]
# [12, 'FUENCARRAL-EL PARDO', 'Despejado', (45, 49), 2]
# [12, 'FUENCARRAL-EL PARDO', 'Despejado', (10, 14), 1]
# [11, 'MONCLOA-ARAVACA', 'Despejado', (-1, -1), 0]
# [10, 'SAN BLAS-CANILLEJAS', '', (45, 49), 14]
# [10, 'SAN BLAS-CANILLEJAS', '', (75, 100), 14]
# [10, 'BARAJAS', '', (40, 44), 0]
# [10, 'BARAJAS', '', (55, 59), 0]
# [10, 'LATINA', 'Despejado', (60, 64), 14]
# [10, 'LATINA', 'Despejado', (65, 69), 14]
# [10, 'VILLA DE VALLECAS', '', (45, 49), 0]
# [10, 'VILLA DE VALLECAS', '', (50, 54), 0]
# [10, 'FUENCARRAL-EL PARDO', '', (45, 49), 0]
# [9, 'HORTALEZA', 'Despejado', (60, 64), 7]
# [9, 'HORTALEZA', 'Despejado', (-1, -1), 0]
# [9, 'BARAJAS', 'Despejado', (45, 49), 0]
# [9, 'BARAJAS', 'Despejado', (35, 39), 0]
# [9, 'BARAJAS', 'Despejado', (30, 34), 0]
# [8, 'CIUDAD LINEAL', 'Despejado', (55, 59), 0]
# [7, 'CENTRO', 'Despejado', (30, 34), 0]
# [5, 'RETIRO', 'Despejado', (50, 54), 14]
# [5, 'RETIRO', 'Despejado', (30, 34), 7]
# [5, 'RETIRO', 'Despejado', (30, 34), 14]
# [3, 'SALAMANCA', 'Despejado', (25, 29), 7]
# [3, 'SALAMANCA', 'Despejado', (55, 59), 14]
# [3, 'SALAMANCA', 'Despejado', (40, 44), 0]
# [3, 'SALAMANCA', 'Despejado', (25, 29), 0]
# [2, 'MONCLOA-ARAVACA', '', (21, 24), 0]
# [1, 'SALAMANCA', 'Despejado', (40, 44), 2]
# [1, 'SALAMANCA', 'Despejado', (25, 29), 3]
# [1, 'SALAMANCA', 'Despejado', (30, 34), 7]
# [23, 'HORTALEZA', 'Despejado', (-1, -1), 0]
# [23, 'HORTALEZA', 'Despejado', (-1, -1), 0]
# [23, 'LATINA', 'Despejado', (60, 64), 14]
# [23, 'LATINA', 'Despejado', (21, 24), 5]
# [23, 'LATINA', 'Despejado', (21, 24), 2]
# [23, 'LATINA', 'Despejado', (18, 20), 2]
# [23, 'VILLAVERDE', 'Despejado', (25, 29), 3]
# [23, 'VILLAVERDE', 'Despejado', (21, 24), 2]
# [23, 'VILLAVERDE', 'Despejado', (21, 24), 2]
# [23, 'VILLAVERDE', 'Despejado', (18, 20), 7]
# [23, 'VILLAVERDE', 'Despejado', (18, 20), 7]
# [23, 'VILLAVERDE', 'Despejado', (15, 17), 7]
# [23, 'VILLAVERDE', 'Despejado', (18, 20), 7]
# [22, 'USERA', '', (21, 24), 14]
# [22, 'USERA', '', (35, 39), 14]
# [22, 'MORATALAZ', 'Despejado', (75, 100), 0]
# [22, 'MORATALAZ', 'Despejado', (50, 54), 0]
# [22, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 0]
# [22, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [22, 'MORATALAZ', 'Despejado', (75, 100), 0]
# [22, 'MORATALAZ', 'Despejado', (21, 24), 0]
# [22, 'CHAMARTÍN', '', (21, 24), 0]
# [22, 'CHAMARTÍN', '', (-1, -1), 0]
# [22, 'CHAMBERÍ', 'Despejado', (50, 54), 0]
# [22, 'CHAMBERÍ', 'Despejado', (35, 39), 0]
# [22, 'CHAMBERÍ', 'Despejado', (30, 34), 14]
# [22, 'VILLA DE VALLECAS', '', (40, 44), 0]
# [22, 'VILLA DE VALLECAS', '', (18, 20), 0]
# [22, 'VILLAVERDE', 'Despejado', (35, 39), 14]
# [22, 'VILLAVERDE', 'Despejado', (25, 29), 2]
# [22, 'PUENTE DE VALLECAS', '', (55, 59), 0]
# [22, 'PUENTE DE VALLECAS', '', (25, 29), 0]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (30, 34), 0]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 0]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (50, 54), 0]
# [21, 'CARABANCHEL', 'Despejado', (40, 44), 7]
# [21, 'CARABANCHEL', 'Despejado', (50, 54), 7]
# [21, 'CARABANCHEL', 'Despejado', (21, 24), 14]
# [21, 'CHAMBERÍ', 'Despejado', (65, 69), 3]
# [21, 'CHAMBERÍ', 'Despejado', (-1, -1), 0]
# [21, 'CHAMBERÍ', 'Despejado', (-1, -1), 0]
# [21, 'CIUDAD LINEAL', 'Despejado', (30, 34), 0]
# [21, 'CIUDAD LINEAL', 'Despejado', (25, 29), 0]
# [21, 'CIUDAD LINEAL', 'Despejado', (25, 29), 0]
# [21, 'CIUDAD LINEAL', 'Despejado', (30, 34), 0]
# [21, 'CARABANCHEL', 'Despejado', (45, 49), 0]
# [21, 'CARABANCHEL', 'Despejado', (25, 29), 0]
# [21, 'PUENTE DE VALLECAS', 'Se desconoce', (25, 29), 14]
# [21, 'PUENTE DE VALLECAS', 'Se desconoce', (50, 54), 1]
# [20, 'CENTRO', 'Despejado', (25, 29), 0]
# [20, 'CENTRO', 'Despejado', (40, 44), 0]
# [20, 'CIUDAD LINEAL', 'Despejado', (35, 39), 14]
# [20, 'CIUDAD LINEAL', 'Despejado', (55, 59), 1]
# [20, 'CARABANCHEL', 'Despejado', (45, 49), 14]
# [20, 'CARABANCHEL', 'Despejado', (35, 39), 14]
# [20, 'CARABANCHEL', 'Despejado', (0, 5), 14]
# [20, 'CARABANCHEL', 'Despejado', (45, 49), 7]
# [20, 'CARABANCHEL', 'Despejado', (40, 44), 7]
# [20, 'CARABANCHEL', 'Despejado', (18, 20), 7]
# [20, 'CARABANCHEL', 'Despejado', (21, 24), 7]
# [20, 'RETIRO', 'Despejado', (75, 100), 0]
# [20, 'RETIRO', 'Despejado', (40, 44), 0]
# [18, 'ARGANZUELA', 'Despejado', (25, 29), 0]
# [18, 'CENTRO', 'Despejado', (55, 59), 0]
# [18, 'CENTRO', 'Despejado', (50, 54), 0]
# [17, 'CIUDAD LINEAL', 'Despejado', (50, 54), 14]
# [17, 'CIUDAD LINEAL', 'Despejado', (65, 69), 3]
# [17, 'VILLA DE VALLECAS', 'Despejado', (35, 39), 0]
# [17, 'VILLA DE VALLECAS', 'Despejado', (25, 29), 0]
# [17, 'SAN BLAS-CANILLEJAS', 'Despejado', (30, 34), 2]
# [17, 'SAN BLAS-CANILLEJAS', 'Despejado', (55, 59), 2]
# [17, 'SAN BLAS-CANILLEJAS', 'Despejado', (0, 5), 7]
# [17, 'SAN BLAS-CANILLEJAS', 'Despejado', (21, 24), 7]
# [16, 'FUENCARRAL-EL PARDO', 'Despejado', (45, 49), 14]
# [16, 'FUENCARRAL-EL PARDO', 'Despejado', (40, 44), 14]
# [16, 'FUENCARRAL-EL PARDO', 'Despejado', (21, 24), 7]
# [16, 'VILLAVERDE', '', (40, 44), 0]
# [15, 'CARABANCHEL', 'Despejado', (15, 17), 6]
# [15, 'CARABANCHEL', 'Despejado', (75, 100), 14]
# [15, 'BARAJAS', 'Despejado', (55, 59), 14]
# [15, 'BARAJAS', 'Despejado', (45, 49), 14]
# [15, 'BARAJAS', 'Despejado', (18, 20), 14]
# [15, 'BARAJAS', 'Despejado', (55, 59), 14]
# [15, 'BARAJAS', 'Despejado', (10, 14), 14]
# [15, 'BARAJAS', 'Despejado', (40, 44), 7]
# [14, 'CHAMARTÍN', 'Despejado', (-1, -1), 0]
# [14, 'CHAMARTÍN', 'Despejado', (35, 39), 7]
# [14, 'SALAMANCA', 'Despejado', (35, 39), 1]
# [14, 'SALAMANCA', 'Despejado', (25, 29), 14]
# [14, 'MORATALAZ', 'Despejado', (30, 34), 0]
# [14, 'MORATALAZ', 'Despejado', (35, 39), 0]
# [14, 'MORATALAZ', 'Despejado', (75, 100), 0]
# [14, 'MORATALAZ', 'Despejado', (55, 59), 0]
# [14, 'VILLA DE VALLECAS', 'Despejado', (30, 34), 7]
# [14, 'VILLA DE VALLECAS', 'Despejado', (35, 39), 7]
# [14, 'VILLA DE VALLECAS', 'Despejado', (50, 54), 14]
# [14, 'MORATALAZ', 'Despejado', (25, 29), 14]
# [14, 'MORATALAZ', 'Despejado', (30, 34), 0]
# [14, 'MORATALAZ', 'Despejado', (35, 39), 14]
# [11, 'TETUÁN', 'Despejado', (35, 39), 14]
# [11, 'TETUÁN', 'Despejado', (75, 100), 2]
# [11, 'CARABANCHEL', 'Despejado', (25, 29), 7]
# [11, 'CARABANCHEL', 'Despejado', (55, 59), 14]
# [11, 'CARABANCHEL', 'Despejado', (40, 44), 14]
# [11, 'CARABANCHEL', 'Despejado', (35, 39), 14]
# [11, 'VILLA DE VALLECAS', 'Despejado', (35, 39), 0]
# [11, 'VILLA DE VALLECAS', 'Despejado', (15, 17), 14]
# [11, 'VILLA DE VALLECAS', 'Despejado', (35, 39), 0]
# [10, 'PUENTE DE VALLECAS', 'Despejado', (45, 49), 0]
# [10, 'PUENTE DE VALLECAS', 'Despejado', (45, 49), 0]
# [10, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 0]
# [10, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 0]
# [6, 'CHAMARTÍN', 'Despejado', (40, 44), 14]
# [6, 'CHAMARTÍN', 'Despejado', (40, 44), 0]
# [6, 'CHAMARTÍN', 'Despejado', (45, 49), 4]
# [4, 'ARGANZUELA', 'Despejado', (21, 24), 14]
# [4, 'ARGANZUELA', 'Despejado', (25, 29), 14]
# [3, 'ARGANZUELA', 'Despejado', (25, 29), 0]
# [3, 'ARGANZUELA', 'Despejado', (30, 34), 0]
# [3, 'ARGANZUELA', 'Despejado', (0, 5), 0]
# [3, 'ARGANZUELA', 'Despejado', (-1, -1), 0]
# [3, 'CARABANCHEL', 'Despejado', (35, 39), 7]
# [3, 'CARABANCHEL', 'Despejado', (25, 29), 14]
# [3, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [1, 'MORATALAZ', 'Despejado', (35, 39), 0]
# [0, 'VILLA DE VALLECAS', 'Despejado', (55, 59), 7]
# [0, 'VILLA DE VALLECAS', 'Despejado', (18, 20), 7]
# [0, 'VILLA DE VALLECAS', 'Despejado', (18, 20), 7]
# [23, 'SAN BLAS-CANILLEJAS', 'Despejado', (45, 49), 0]
# [23, 'SAN BLAS-CANILLEJAS', 'Despejado', (35, 39), 0]
# [22, 'TETUÁN', 'Despejado', (35, 39), 14]
# [22, 'TETUÁN', 'Despejado', (40, 44), 7]
# [22, 'TETUÁN', 'Despejado', (21, 24), 14]
# [22, 'TETUÁN', 'Despejado', (40, 44), 0]
# [22, 'TETUÁN', 'Despejado', (-1, -1), 0]
# [22, 'CHAMBERÍ', 'Despejado', (60, 64), 7]
# [21, 'LATINA', 'Despejado', (-1, -1), 0]
# [21, 'LATINA', 'Despejado', (45, 49), 0]
# [21, 'SALAMANCA', '', (40, 44), 0]
# [21, 'SALAMANCA', '', (30, 34), 0]
# [20, 'RETIRO', 'Despejado', (30, 34), 0]
# [20, 'RETIRO', 'Despejado', (30, 34), 0]
# [19, 'RETIRO', 'Despejado', (25, 29), 0]
# [19, 'RETIRO', 'Despejado', (60, 64), 0]
# [19, 'RETIRO', 'Despejado', (55, 59), 0]
# [19, 'RETIRO', 'Despejado', (18, 20), 0]
# [19, 'CHAMARTÍN', '', (35, 39), 0]
# [19, 'CHAMARTÍN', '', (-1, -1), 0]
# [19, 'RETIRO', 'Despejado', (21, 24), 14]
# [19, 'RETIRO', 'Despejado', (35, 39), 14]
# [19, 'RETIRO', 'Despejado', (30, 34), 7]
# [19, 'RETIRO', 'Despejado', (35, 39), 14]
# [19, 'RETIRO', 'Despejado', (40, 44), 0]
# [19, 'RETIRO', 'Despejado', (-1, -1), 0]
# [19, 'LATINA', 'Despejado', (55, 59), 0]
# [18, 'PUENTE DE VALLECAS', 'Despejado', (40, 44), 0]
# [18, 'PUENTE DE VALLECAS', 'Despejado', (21, 24), 0]
# [18, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 0]
# [18, 'PUENTE DE VALLECAS', 'Despejado', (60, 64), 0]
# [18, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 0]
# [18, 'ARGANZUELA', 'Despejado', (18, 20), 0]
# [18, 'ARGANZUELA', 'Despejado', (65, 69), 0]
# [18, 'ARGANZUELA', 'Despejado', (70, 74), 0]
# [18, 'CHAMBERÍ', 'Despejado', (45, 49), 0]
# [18, 'CHAMBERÍ', 'Despejado', (55, 59), 0]
# [18, 'CHAMBERÍ', 'Despejado', (-1, -1), 0]
# [18, 'CHAMBERÍ', 'Despejado', (70, 74), 0]
# [18, 'CHAMBERÍ', 'Despejado', (45, 49), 0]
# [18, 'ARGANZUELA', 'Despejado', (45, 49), 14]
# [18, 'ARGANZUELA', 'Despejado', (30, 34), 14]
# [18, 'ARGANZUELA', 'Despejado', (40, 44), 6]
# [18, 'ARGANZUELA', 'Despejado', (0, 5), 6]
# [18, 'ARGANZUELA', 'Despejado', (40, 44), 14]
# [18, 'ARGANZUELA', 'Despejado', (40, 44), 14]
# [18, 'ARGANZUELA', 'Despejado', (10, 14), 7]
# [18, 'ARGANZUELA', 'Despejado', (35, 39), 14]
# [18, 'ARGANZUELA', 'Despejado', (18, 20), 7]
# [18, 'ARGANZUELA', 'Despejado', (45, 49), 14]
# [18, 'ARGANZUELA', 'Despejado', (65, 69), 14]
# [18, 'CARABANCHEL', 'Despejado', (30, 34), 2]
# [18, 'CARABANCHEL', 'Despejado', (40, 44), 14]
# [18, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [18, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [18, 'VILLAVERDE', 'Despejado', (45, 49), 14]
# [18, 'VILLAVERDE', 'Despejado', (18, 20), 2]
# [17, 'MORATALAZ', 'Despejado', (35, 39), 14]
# [17, 'MORATALAZ', 'Despejado', (55, 59), 7]
# [16, 'CHAMARTÍN', 'Despejado', (50, 54), 14]
# [16, 'CHAMARTÍN', 'Despejado', (18, 20), 14]
# [16, 'CHAMARTÍN', 'Despejado', (35, 39), 7]
# [16, 'CHAMARTÍN', 'Despejado', (-1, -1), 0]
# [16, 'LATINA', 'Despejado', (45, 49), 0]
# [16, 'LATINA', 'Despejado', (30, 34), 0]
# [16, 'LATINA', 'Despejado', (25, 29), 0]
# [16, 'CHAMBERÍ', 'Despejado', (21, 24), 14]
# [16, 'CHAMBERÍ', 'Despejado', (55, 59), 14]
# [16, 'CHAMBERÍ', 'Despejado', (75, 100), 6]
# [16, 'LATINA', 'Despejado', (70, 74), 0]
# [16, 'LATINA', 'Despejado', (21, 24), 0]
# [16, 'RETIRO', 'Despejado', (30, 34), 14]
# [16, 'RETIRO', 'Despejado', (50, 54), 7]
# [15, 'CARABANCHEL', 'Despejado', (55, 59), 0]
# [15, 'CARABANCHEL', 'Despejado', (21, 24), 0]
# [14, 'MONCLOA-ARAVACA', 'Despejado', (40, 44), 7]
# [14, 'MONCLOA-ARAVACA', 'Despejado', (30, 34), 14]
# [14, 'MONCLOA-ARAVACA', 'Despejado', (25, 29), 7]
# [14, 'MONCLOA-ARAVACA', 'Despejado', (35, 39), 14]
# [14, 'MONCLOA-ARAVACA', 'Despejado', (0, 5), 7]
# [14, 'MONCLOA-ARAVACA', 'Despejado', (35, 39), 14]
# [13, 'CIUDAD LINEAL', 'Despejado', (50, 54), 3]
# [13, 'CIUDAD LINEAL', 'Despejado', (35, 39), 14]
# [13, 'CIUDAD LINEAL', 'Despejado', (25, 29), 7]
# [13, 'CIUDAD LINEAL', 'Despejado', (60, 64), 7]
# [13, 'CIUDAD LINEAL', 'Despejado', (0, 5), 7]
# [12, 'PUENTE DE VALLECAS', 'Despejado', (50, 54), 0]
# [12, 'PUENTE DE VALLECAS', 'Despejado', (45, 49), 0]
# [11, 'CARABANCHEL', 'Despejado', (30, 34), 14]
# [11, 'CARABANCHEL', 'Despejado', (55, 59), 2]
# [11, 'TETUÁN', '', (-1, -1), 0]
# [11, 'TETUÁN', '', (-1, -1), 0]
# [11, 'TETUÁN', '', (-1, -1), 0]
# [9, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 7]
# [9, 'PUENTE DE VALLECAS', 'Despejado', (25, 29), 14]
# [8, 'PUENTE DE VALLECAS', 'Despejado', (40, 44), 0]
# [8, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [7, 'CARABANCHEL', 'Despejado', (35, 39), 14]
# [7, 'CARABANCHEL', 'Despejado', (55, 59), 14]
# [7, 'CARABANCHEL', 'Despejado', (35, 39), 14]
# [7, 'CARABANCHEL', 'Despejado', (25, 29), 14]
# [7, 'CARABANCHEL', 'Despejado', (50, 54), 5]
# [7, 'CARABANCHEL', 'Despejado', (35, 39), 5]
# [7, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [7, 'VILLAVERDE', 'Despejado', (21, 24), 0]
# [7, 'VILLAVERDE', 'Despejado', (21, 24), 0]
# [7, 'VILLAVERDE', 'Despejado', (21, 24), 0]
# [7, 'VILLAVERDE', 'Despejado', (-1, -1), 0]
# [7, 'VILLAVERDE', 'Despejado', (-1, -1), 0]
# [3, 'CIUDAD LINEAL', 'Despejado', (35, 39), 14]
# [3, 'CIUDAD LINEAL', 'Despejado', (35, 39), 14]
# [3, 'CIUDAD LINEAL', 'Despejado', (-1, -1), 0]
# [3, 'CIUDAD LINEAL', 'Despejado', (-1, -1), 0]
# [2, 'RETIRO', 'Despejado', (25, 29), 6]
# [1, 'CHAMARTÍN', 'Despejado', (65, 69), 14]
# [1, 'CHAMARTÍN', 'Despejado', (75, 100), 14]
# [1, 'CHAMARTÍN', 'Despejado', (70, 74), 14]
# [1, 'CHAMARTÍN', 'Despejado', (45, 49), 5]
# [1, 'CHAMARTÍN', 'Despejado', (40, 44), 14]
# [1, 'RETIRO', 'Despejado', (35, 39), 2]
# [1, 'RETIRO', 'Despejado', (55, 59), 14]
# [1, 'RETIRO', 'Despejado', (40, 44), 14]
# [0, 'CENTRO', 'Despejado', (21, 24), 7]
# [0, 'MONCLOA-ARAVACA', '', (21, 24), 0]
# [0, 'MONCLOA-ARAVACA', '', (-1, -1), 0]
# [0, 'MONCLOA-ARAVACA', '', (-1, -1), 0]
# [0, 'MONCLOA-ARAVACA', '', (-1, -1), 0]
# [0, 'MONCLOA-ARAVACA', '', (-1, -1), 0]
# [21, 'SAN BLAS-CANILLEJAS', 'Despejado', (50, 54), 7]
# [21, 'SAN BLAS-CANILLEJAS', 'Despejado', (-1, -1), 0]
# [21, 'SAN BLAS-CANILLEJAS', 'Despejado', (18, 20), 14]
# [21, 'SAN BLAS-CANILLEJAS', 'Despejado', (35, 39), 14]
# [21, 'LATINA', '', (55, 59), 0]
# [21, 'HORTALEZA', 'Despejado', (21, 24), 14]
# [21, 'HORTALEZA', 'Despejado', (45, 49), 7]
# [21, 'HORTALEZA', 'Despejado', (10, 14), 7]
# [21, 'TETUÁN', 'Despejado', (50, 54), 0]
# [21, 'TETUÁN', 'Despejado', (75, 100), 0]
# [21, 'TETUÁN', 'Despejado', (70, 74), 0]
# [21, 'RETIRO', 'Despejado', (-1, -1), 0]
# [21, 'RETIRO', 'Despejado', (-1, -1), 0]
# [20, 'SALAMANCA', 'Despejado', (40, 44), 14]
# [20, 'SALAMANCA', 'Despejado', (30, 34), 6]
# [20, 'FUENCARRAL-EL PARDO', 'Despejado', (60, 64), 0]
# [20, 'FUENCARRAL-EL PARDO', 'Despejado', (60, 64), 0]
# [19, 'CENTRO', '', (75, 100), 14]
# [19, 'CENTRO', '', (75, 100), 0]
# [19, 'MONCLOA-ARAVACA', 'Despejado', (40, 44), 7]
# [19, 'MONCLOA-ARAVACA', 'Despejado', (30, 34), 7]
# [19, 'MONCLOA-ARAVACA', 'Despejado', (55, 59), 7]
# [19, 'CIUDAD LINEAL', 'Despejado', (25, 29), 14]
# [19, 'CIUDAD LINEAL', 'Despejado', (55, 59), 6]
# [19, 'CIUDAD LINEAL', 'Despejado', (35, 39), 14]
# [18, 'TETUÁN', 'Despejado', (25, 29), 7]
# [18, 'TETUÁN', 'Despejado', (-1, -1), 0]
# [18, 'TETUÁN', 'Despejado', (-1, -1), 0]
# [18, 'ARGANZUELA', '', (75, 100), 14]
# [18, 'ARGANZUELA', '', (-1, -1), 0]
# [18, 'BARAJAS', 'Despejado', (35, 39), 14]
# [18, 'BARAJAS', 'Despejado', (45, 49), 7]
# [18, 'SALAMANCA', 'Despejado', (50, 54), 0]
# [18, 'SALAMANCA', 'Despejado', (35, 39), 0]
# [18, 'SALAMANCA', 'Despejado', (-1, -1), 0]
# [17, 'BARAJAS', 'Despejado', (25, 29), 14]
# [17, 'BARAJAS', 'Despejado', (30, 34), 2]
# [16, 'FUENCARRAL-EL PARDO', 'Despejado', (75, 100), 0]
# [16, 'FUENCARRAL-EL PARDO', 'Despejado', (40, 44), 0]
# [16, 'FUENCARRAL-EL PARDO', 'Despejado', (-1, -1), 0]
# [16, 'FUENCARRAL-EL PARDO', 'Despejado', (-1, -1), 0]
# [16, 'TETUÁN', 'Despejado', (25, 29), 7]
# [16, 'TETUÁN', 'Despejado', (25, 29), 7]
# [16, 'TETUÁN', 'Despejado', (25, 29), 14]
# [16, 'TETUÁN', 'Despejado', (25, 29), 7]
# [16, 'PUENTE DE VALLECAS', 'Despejado', (30, 34), 0]
# [16, 'PUENTE DE VALLECAS', 'Despejado', (45, 49), 0]
# [16, 'PUENTE DE VALLECAS', 'Despejado', (45, 49), 0]
# [16, 'CARABANCHEL', 'Despejado', (25, 29), 7]
# [16, 'CARABANCHEL', 'Despejado', (21, 24), 14]
# [16, 'CARABANCHEL', 'Despejado', (30, 34), 6]
# [16, 'VILLA DE VALLECAS', 'Despejado', (30, 34), 2]
# [16, 'TETUÁN', 'Despejado', (50, 54), 0]
# [15, 'MORATALAZ', 'Despejado', (40, 44), 5]
# [15, 'MORATALAZ', 'Despejado', (25, 29), 14]
# [15, 'MONCLOA-ARAVACA', 'Despejado', (40, 44), 0]
# [15, 'MONCLOA-ARAVACA', 'Despejado', (45, 49), 0]
# [15, 'FUENCARRAL-EL PARDO', 'Despejado', (50, 54), 7]
# [15, 'FUENCARRAL-EL PARDO', 'Despejado', (40, 44), 14]
# [14, 'CHAMARTÍN', '', (40, 44), 0]
# [14, 'CHAMARTÍN', '', (50, 54), 0]
# [14, 'HORTALEZA', 'Despejado', (35, 39), 14]
# [14, 'HORTALEZA', 'Despejado', (35, 39), 7]
# [14, 'HORTALEZA', 'Despejado', (50, 54), 14]
# [14, 'HORTALEZA', 'Despejado', (45, 49), 14]
# [14, 'HORTALEZA', 'Despejado', (30, 34), 7]
# [14, 'RETIRO', 'Despejado', (65, 69), 14]
# [14, 'RETIRO', 'Despejado', (25, 29), 7]
# [13, 'SAN BLAS-CANILLEJAS', 'Despejado', (65, 69), 0]
# [13, 'SAN BLAS-CANILLEJAS', 'Despejado', (45, 49), 0]
# [13, 'ARGANZUELA', 'Despejado', (40, 44), 0]
# [13, 'ARGANZUELA', 'Despejado', (40, 44), 0]
# [13, 'CHAMARTÍN', 'Despejado', (65, 69), 14]
# [13, 'CHAMARTÍN', 'Despejado', (40, 44), 7]
# [13, 'CHAMARTÍN', 'Despejado', (35, 39), 14]
# [13, 'CHAMARTÍN', 'Despejado', (6, 9), 7]
# [13, 'CHAMARTÍN', 'Despejado', (40, 44), 14]
# [13, 'CIUDAD LINEAL', 'Despejado', (50, 54), 0]
# [13, 'CIUDAD LINEAL', 'Despejado', (70, 74), 0]
# [13, 'CIUDAD LINEAL', 'Despejado', (70, 74), 0]
# [13, 'ARGANZUELA', 'Despejado', (45, 49), 14]
# [13, 'ARGANZUELA', 'Despejado', (45, 49), 5]
# [13, 'CIUDAD LINEAL', 'Despejado', (30, 34), 7]
# [13, 'CIUDAD LINEAL', 'Despejado', (25, 29), 14]
# [13, 'CIUDAD LINEAL', 'Despejado', (45, 49), 14]
# [13, 'PUENTE DE VALLECAS', 'Despejado', (60, 64), 14]
# [13, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 14]
# [13, 'PUENTE DE VALLECAS', 'Despejado', (30, 34), 2]
# [13, 'TETUÁN', 'Despejado', (30, 34), 0]
# [13, 'TETUÁN', 'Despejado', (45, 49), 0]
# [13, 'RETIRO', 'Despejado', (35, 39), 14]
# [13, 'RETIRO', 'Despejado', (0, 5), 7]
# [12, 'SALAMANCA', 'Despejado', (55, 59), 0]
# [12, 'SALAMANCA', 'Despejado', (30, 34), 0]
# [12, 'RETIRO', 'Despejado', (60, 64), 7]
# [12, 'RETIRO', 'Despejado', (60, 64), 3]
# [12, 'CHAMBERÍ', 'Despejado', (35, 39), 3]
# [11, 'SALAMANCA', 'Despejado', (45, 49), 7]
# [11, 'SALAMANCA', 'Despejado', (35, 39), 14]
# [10, 'CHAMARTÍN', '', (-1, -1), 0]
# [10, 'CHAMARTÍN', '', (65, 69), 0]
# [10, 'ARGANZUELA', 'Despejado', (45, 49), 14]
# [10, 'FUENCARRAL-EL PARDO', 'Despejado', (30, 34), 5]
# [10, 'FUENCARRAL-EL PARDO', 'Despejado', (75, 100), 14]
# [10, 'FUENCARRAL-EL PARDO', 'Despejado', (75, 100), 5]
# [10, 'CHAMARTÍN', 'Despejado', (55, 59), 14]
# [9, 'MORATALAZ', 'Despejado', (25, 29), 14]
# [9, 'MORATALAZ', 'Despejado', (30, 34), 3]
# [9, 'TETUÁN', 'Despejado', (40, 44), 1]
# [9, 'TETUÁN', 'Despejado', (35, 39), 14]
# [9, 'SAN BLAS-CANILLEJAS', 'Despejado', (30, 34), 14]
# [9, 'SAN BLAS-CANILLEJAS', 'Despejado', (45, 49), 1]
# [8, 'HORTALEZA', 'Despejado', (50, 54), 7]
# [7, 'FUENCARRAL-EL PARDO', 'Despejado', (50, 54), 14]
# [7, 'FUENCARRAL-EL PARDO', 'Despejado', (55, 59), 1]
# [7, 'MONCLOA-ARAVACA', 'Despejado', (55, 59), 2]
# [7, 'MONCLOA-ARAVACA', 'Despejado', (25, 29), 2]
# [7, 'FUENCARRAL-EL PARDO', 'Despejado', (45, 49), 0]
# [6, 'MONCLOA-ARAVACA', 'Lluvia débil', (75, 100), 14]
# [0, 'MONCLOA-ARAVACA', 'Despejado', (35, 39), 1]
# [0, 'MONCLOA-ARAVACA', 'Despejado', (35, 39), 1]
# [0, 'MONCLOA-ARAVACA', 'Despejado', (50, 54), 2]
# [23, 'LATINA', 'Despejado', (50, 54), 14]
# [23, 'LATINA', 'Despejado', (35, 39), 3]
# [23, 'HORTALEZA', 'Despejado', (30, 34), 0]
# [23, 'LATINA', 'Se desconoce', (18, 20), 14]
# [23, 'LATINA', 'Se desconoce', (21, 24), 14]
# [23, 'LATINA', 'Se desconoce', (55, 59), 7]
# [22, 'LATINA', 'Despejado', (35, 39), 1]
# [22, 'USERA', 'Despejado', (35, 39), 14]
# [22, 'USERA', 'Despejado', (40, 44), 14]
# [22, 'USERA', 'Despejado', (55, 59), 7]
# [21, 'VICÁLVARO', '', (45, 49), 0]
# [21, 'VICÁLVARO', '', (30, 34), 0]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (18, 20), 14]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 14]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 2]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (60, 64), 14]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (21, 24), 14]
# [20, 'SALAMANCA', 'Despejado', (21, 24), 0]
# [20, 'SALAMANCA', 'Despejado', (55, 59), 0]
# [20, 'SALAMANCA', 'Despejado', (50, 54), 0]
# [20, 'SALAMANCA', 'Despejado', (25, 29), 0]
# [20, 'SALAMANCA', 'Despejado', (35, 39), 0]
# [20, 'VILLA DE VALLECAS', 'Se desconoce', (30, 34), 0]
# [20, 'VILLA DE VALLECAS', 'Se desconoce', (45, 49), 0]
# [20, 'VILLA DE VALLECAS', 'Se desconoce', (45, 49), 0]
# [20, 'VILLA DE VALLECAS', 'Se desconoce', (30, 34), 0]
# [20, 'VILLA DE VALLECAS', 'Se desconoce', (35, 39), 0]
# [20, 'VILLA DE VALLECAS', 'Se desconoce', (55, 59), 0]
# [20, 'VILLA DE VALLECAS', 'Se desconoce', (70, 74), 0]
# [20, 'LATINA', 'Despejado', (21, 24), 14]
# [20, 'LATINA', 'Despejado', (50, 54), 14]
# [20, 'LATINA', 'Despejado', (21, 24), 7]
# [20, 'LATINA', 'Despejado', (18, 20), 7]
# [20, 'CARABANCHEL', 'Despejado', (30, 34), 0]
# [20, 'CARABANCHEL', 'Despejado', (45, 49), 0]
# [20, 'HORTALEZA', 'Despejado', (75, 100), 14]
# [20, 'HORTALEZA', 'Despejado', (25, 29), 7]
# [19, 'CENTRO', 'Despejado', (40, 44), 7]
# [19, 'CENTRO', 'Despejado', (21, 24), 7]
# [19, 'LATINA', 'Despejado', (60, 64), 2]
# [19, 'LATINA', 'Despejado', (25, 29), 14]
# [19, 'SAN BLAS-CANILLEJAS', 'Despejado', (50, 54), 0]
# [19, 'SAN BLAS-CANILLEJAS', 'Despejado', (-1, -1), 0]
# [19, 'SAN BLAS-CANILLEJAS', 'Despejado', (-1, -1), 0]
# [19, 'SAN BLAS-CANILLEJAS', 'Despejado', (-1, -1), 0]
# [19, 'RETIRO', 'Despejado', (18, 20), 14]
# [19, 'RETIRO', 'Despejado', (25, 29), 6]
# [19, 'RETIRO', 'Despejado', (35, 39), 14]
# [19, 'MORATALAZ', 'Despejado', (75, 100), 14]
# [19, 'MORATALAZ', 'Despejado', (30, 34), 7]
# [19, 'CENTRO', 'Despejado', (40, 44), 14]
# [19, 'CENTRO', 'Despejado', (18, 20), 14]
# [19, 'CENTRO', 'Despejado', (21, 24), 7]
# [19, 'CIUDAD LINEAL', 'Despejado', (21, 24), 0]
# [19, 'CIUDAD LINEAL', 'Despejado', (65, 69), 0]
# [19, 'VICÁLVARO', 'Despejado', (40, 44), 0]
# [19, 'VICÁLVARO', 'Despejado', (10, 14), 0]
# [19, 'VICÁLVARO', 'Despejado', (40, 44), 0]
# [18, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [18, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [18, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [18, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [18, 'CHAMARTÍN', 'Despejado', (70, 74), 14]
# [18, 'CHAMARTÍN', 'Despejado', (35, 39), 5]
# [18, 'HORTALEZA', 'Despejado', (21, 24), 14]
# [18, 'HORTALEZA', 'Despejado', (60, 64), 14]
# [18, 'HORTALEZA', 'Despejado', (-1, -1), 0]
# [18, 'BARAJAS', 'Despejado', (21, 24), 2]
# [18, 'BARAJAS', 'Despejado', (-1, -1), 0]
# [17, 'VILLA DE VALLECAS', 'Despejado', (25, 29), 0]
# [17, 'VILLA DE VALLECAS', 'Despejado', (40, 44), 0]
# [17, 'ARGANZUELA', 'Despejado', (55, 59), 14]
# [17, 'ARGANZUELA', 'Despejado', (65, 69), 3]
# [17, 'VILLA DE VALLECAS', 'Lluvia débil', (40, 44), 14]
# [17, 'VILLA DE VALLECAS', 'Lluvia débil', (45, 49), 7]
# [17, 'VILLA DE VALLECAS', 'Lluvia débil', (45, 49), 14]
# [17, 'VILLA DE VALLECAS', 'Lluvia débil', (40, 44), 14]
# [17, 'SALAMANCA', 'Despejado', (45, 49), 0]
# [17, 'SALAMANCA', 'Despejado', (55, 59), 0]
# [17, 'CHAMARTÍN', '', (40, 44), 0]
# [17, 'CHAMARTÍN', '', (-1, -1), 0]
# [17, 'CHAMARTÍN', '', (55, 59), 0]
# [17, 'CHAMARTÍN', '', (55, 59), 0]
# [17, 'TETUÁN', 'Despejado', (21, 24), 1]
# [17, 'TETUÁN', 'Despejado', (21, 24), 1]
# [17, 'TETUÁN', 'Despejado', (21, 24), 14]
# [17, 'TETUÁN', 'Despejado', (25, 29), 14]
# [16, 'MONCLOA-ARAVACA', 'Despejado', (-1, -1), 0]
# [16, 'RETIRO', '', (60, 64), 0]
# [16, 'RETIRO', '', (55, 59), 0]
# [15, 'PUENTE DE VALLECAS', 'Despejado', (75, 100), 14]
# [15, 'PUENTE DE VALLECAS', 'Despejado', (18, 20), 6]
# [15, 'CHAMBERÍ', 'Despejado', (30, 34), 7]
# [15, 'CHAMBERÍ', 'Despejado', (45, 49), 7]
# [15, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [15, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [15, 'RETIRO', 'Despejado', (30, 34), 14]
# [15, 'RETIRO', 'Despejado', (45, 49), 6]
# [15, 'RETIRO', 'Despejado', (35, 39), 14]
# [14, 'CHAMARTÍN', 'Despejado', (15, 17), 7]
# [14, 'CHAMARTÍN', 'Despejado', (60, 64), 14]
# [14, 'PUENTE DE VALLECAS', 'Despejado', (70, 74), 0]
# [14, 'PUENTE DE VALLECAS', 'Despejado', (65, 69), 0]
# [14, 'PUENTE DE VALLECAS', 'Despejado', (60, 64), 0]
# [14, 'PUENTE DE VALLECAS', 'Despejado', (65, 69), 0]
# [14, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 0]
# [14, 'FUENCARRAL-EL PARDO', 'Despejado', (45, 49), 0]
# [14, 'FUENCARRAL-EL PARDO', 'Despejado', (55, 59), 0]
# [14, 'MORATALAZ', 'Despejado', (75, 100), 0]
# [14, 'MORATALAZ', 'Despejado', (65, 69), 0]
# [14, 'SAN BLAS-CANILLEJAS', 'Despejado', (70, 74), 14]
# [14, 'SAN BLAS-CANILLEJAS', 'Despejado', (45, 49), 14]
# [14, 'FUENCARRAL-EL PARDO', 'Despejado', (70, 74), 0]
# [14, 'FUENCARRAL-EL PARDO', 'Despejado', (-1, -1), 0]
# [14, 'CHAMBERÍ', 'Despejado', (55, 59), 14]
# [14, 'CHAMBERÍ', 'Despejado', (50, 54), 14]
# [14, 'CHAMBERÍ', 'Despejado', (75, 100), 7]
# [14, 'CHAMBERÍ', 'Despejado', (35, 39), 6]
# [14, 'CHAMBERÍ', 'Despejado', (35, 39), 6]
# [14, 'CHAMBERÍ', 'Despejado', (30, 34), 14]
# [13, 'SAN BLAS-CANILLEJAS', 'Despejado', (40, 44), 14]
# [13, 'SAN BLAS-CANILLEJAS', 'Despejado', (50, 54), 7]
# [13, 'MONCLOA-ARAVACA', 'Despejado', (45, 49), 0]
# [13, 'MONCLOA-ARAVACA', 'Despejado', (75, 100), 0]
# [13, 'MONCLOA-ARAVACA', 'Despejado', (25, 29), 0]
# [13, 'MONCLOA-ARAVACA', 'Despejado', (-1, -1), 0]
# [13, 'LATINA', 'Despejado', (30, 34), 0]
# [13, 'LATINA', 'Despejado', (-1, -1), 0]
# [13, 'LATINA', 'Despejado', (-1, -1), 0]
# [13, 'MONCLOA-ARAVACA', 'Despejado', (65, 69), 14]
# [13, 'MONCLOA-ARAVACA', 'Despejado', (50, 54), 2]
# [12, 'FUENCARRAL-EL PARDO', 'Despejado', (40, 44), 0]
# [12, 'FUENCARRAL-EL PARDO', 'Despejado', (45, 49), 0]
# [12, 'FUENCARRAL-EL PARDO', 'Despejado', (60, 64), 0]
# [11, 'CIUDAD LINEAL', 'Despejado', (35, 39), 4]
# [11, 'CIUDAD LINEAL', 'Despejado', (40, 44), 14]
# [11, 'CIUDAD LINEAL', 'Despejado', (55, 59), 7]
# [11, 'SAN BLAS-CANILLEJAS', 'Despejado', (70, 74), 1]
# [11, 'SAN BLAS-CANILLEJAS', 'Despejado', (65, 69), 1]
# [11, 'MONCLOA-ARAVACA', 'Despejado', (75, 100), 14]
# [11, 'MONCLOA-ARAVACA', 'Despejado', (75, 100), 6]
# [11, 'MONCLOA-ARAVACA', 'Nublado', (55, 59), 14]
# [11, 'MONCLOA-ARAVACA', 'Nublado', (40, 44), 7]
# [9, 'LATINA', 'Despejado', (35, 39), 14]
# [9, 'LATINA', 'Despejado', (60, 64), 14]
# [8, 'CARABANCHEL', 'Despejado', (30, 34), 7]
# [8, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [8, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [8, 'CHAMBERÍ', 'Despejado', (45, 49), 14]
# [8, 'CHAMBERÍ', 'Despejado', (35, 39), 1]
# [8, 'CENTRO', 'Despejado', (40, 44), 0]
# [8, 'CENTRO', 'Despejado', (35, 39), 0]
# [8, 'CIUDAD LINEAL', 'Despejado', (-1, -1), 0]
# [8, 'CIUDAD LINEAL', 'Despejado', (30, 34), 0]
# [7, 'MORATALAZ', 'Despejado', (35, 39), 0]
# [7, 'VILLA DE VALLECAS', 'Despejado', (60, 64), 14]
# [7, 'VILLA DE VALLECAS', 'Despejado', (18, 20), 5]
# [6, 'TETUÁN', 'Despejado', (18, 20), 14]
# [6, 'TETUÁN', 'Despejado', (40, 44), 1]
# [6, 'TETUÁN', 'Despejado', (40, 44), 14]
# [5, 'PUENTE DE VALLECAS', 'Despejado', (40, 44), 0]
# [5, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [0, 'ARGANZUELA', 'Despejado', (35, 39), 0]
# [0, 'ARGANZUELA', 'Despejado', (30, 34), 0]
# [23, 'CHAMARTÍN', 'Despejado', (40, 44), 0]
# [23, 'CHAMARTÍN', 'Despejado', (-1, -1), 0]
# [23, 'VILLA DE VALLECAS', 'Despejado', (18, 20), 0]
# [23, 'VILLA DE VALLECAS', 'Despejado', (-1, -1), 0]
# [22, 'BARAJAS', 'Despejado', (35, 39), 0]
# [22, 'BARAJAS', 'Despejado', (30, 34), 0]
# [21, 'SAN BLAS-CANILLEJAS', '', (40, 44), 0]
# [21, 'CIUDAD LINEAL', 'Despejado', (35, 39), 6]
# [21, 'CIUDAD LINEAL', 'Despejado', (55, 59), 6]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (50, 54), 6]
# [21, 'LATINA', 'Despejado', (55, 59), 0]
# [21, 'LATINA', 'Despejado', (-1, -1), 0]
# [21, 'CENTRO', 'Despejado', (30, 34), 14]
# [21, 'CENTRO', 'Despejado', (21, 24), 14]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 0]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (21, 24), 0]
# [20, 'HORTALEZA', 'Nublado', (50, 54), 14]
# [20, 'HORTALEZA', 'Nublado', (40, 44), 14]
# [20, 'HORTALEZA', 'Nublado', (-1, -1), 0]
# [20, 'SALAMANCA', 'Despejado', (35, 39), 0]
# [20, 'SALAMANCA', 'Despejado', (30, 34), 0]
# [19, 'CENTRO', 'Despejado', (50, 54), 7]
# [19, 'CENTRO', 'Despejado', (18, 20), 14]
# [19, 'CARABANCHEL', 'Despejado', (30, 34), 14]
# [19, 'CARABANCHEL', 'Despejado', (30, 34), 7]
# [19, 'HORTALEZA', 'Despejado', (45, 49), 14]
# [19, 'HORTALEZA', 'Despejado', (25, 29), 7]
# [19, 'SALAMANCA', 'Despejado', (75, 100), 14]
# [19, 'SALAMANCA', 'Despejado', (30, 34), 6]
# [19, 'RETIRO', '', (45, 49), 0]
# [19, 'RETIRO', '', (40, 44), 0]
# [19, 'TETUÁN', 'Despejado', (25, 29), 0]
# [19, 'TETUÁN', 'Despejado', (21, 24), 0]
# [18, 'MORATALAZ', 'Despejado', (35, 39), 7]
# [18, 'MORATALAZ', 'Despejado', (45, 49), 7]
# [18, 'CIUDAD LINEAL', 'Despejado', (50, 54), 14]
# [18, 'CIUDAD LINEAL', 'Despejado', (40, 44), 7]
# [18, 'CENTRO', 'Despejado', (50, 54), 0]
# [18, 'CENTRO', 'Despejado', (75, 100), 0]
# [18, 'CARABANCHEL', 'Despejado', (30, 34), 14]
# [18, 'CARABANCHEL', 'Despejado', (30, 34), 14]
# [18, 'CHAMARTÍN', 'Despejado', (40, 44), 5]
# [18, 'CHAMARTÍN', 'Despejado', (60, 64), 14]
# [17, 'CHAMARTÍN', 'Despejado', (35, 39), 14]
# [17, 'SAN BLAS-CANILLEJAS', 'Despejado', (50, 54), 6]
# [17, 'SAN BLAS-CANILLEJAS', 'Despejado', (45, 49), 14]
# [17, 'CARABANCHEL', '', (45, 49), 0]
# [17, 'CARABANCHEL', '', (45, 49), 0]
# [17, 'CARABANCHEL', '', (40, 44), 0]
# [17, 'CARABANCHEL', '', (0, 5), 0]
# [17, 'ARGANZUELA', 'Despejado', (50, 54), 7]
# [17, 'ARGANZUELA', 'Despejado', (35, 39), 14]
# [17, 'ARGANZUELA', 'Despejado', (30, 34), 14]
# [17, 'HORTALEZA', 'Despejado', (35, 39), 14]
# [17, 'HORTALEZA', 'Despejado', (30, 34), 14]
# [16, 'ARGANZUELA', '', (55, 59), 0]
# [16, 'ARGANZUELA', '', (35, 39), 0]
# [16, 'VILLA DE VALLECAS', 'Despejado', (30, 34), 0]
# [16, 'VILLA DE VALLECAS', 'Despejado', (55, 59), 0]
# [15, 'VILLA DE VALLECAS', '', (30, 34), 0]
# [15, 'VILLA DE VALLECAS', '', (35, 39), 0]
# [15, 'HORTALEZA', 'Despejado', (50, 54), 2]
# [15, 'HORTALEZA', 'Despejado', (45, 49), 7]
# [15, 'FUENCARRAL-EL PARDO', 'Despejado', (40, 44), 14]
# [15, 'FUENCARRAL-EL PARDO', 'Despejado', (40, 44), 6]
# [15, 'FUENCARRAL-EL PARDO', 'Despejado', (40, 44), 7]
# [15, 'LATINA', 'Despejado', (50, 54), 14]
# [15, 'LATINA', 'Despejado', (35, 39), 7]
# [15, 'SAN BLAS-CANILLEJAS', '', (30, 34), 14]
# [15, 'SAN BLAS-CANILLEJAS', '', (45, 49), 14]
# [15, 'SAN BLAS-CANILLEJAS', '', (50, 54), 14]
# [14, 'USERA', 'Despejado', (55, 59), 14]
# [14, 'USERA', 'Despejado', (6, 9), 14]
# [13, 'VICÁLVARO', 'Despejado', (30, 34), 14]
# [13, 'VICÁLVARO', 'Despejado', (25, 29), 7]
# [13, 'ARGANZUELA', 'Despejado', (25, 29), 0]
# [13, 'ARGANZUELA', 'Despejado', (55, 59), 0]
# [13, 'MORATALAZ', 'Despejado', (75, 100), 0]
# [13, 'MORATALAZ', 'Despejado', (75, 100), 0]
# [13, 'CHAMARTÍN', 'Despejado', (-1, -1), 0]
# [13, 'CHAMARTÍN', 'Despejado', (60, 64), 5]
# [13, 'BARAJAS', 'Despejado', (50, 54), 0]
# [13, 'SALAMANCA', 'Despejado', (35, 39), 0]
# [13, 'SALAMANCA', 'Despejado', (35, 39), 0]
# ...
# [16, 'CHAMARTÍN', 'Despejado', (45, 49), 0]
# [16, 'CHAMARTÍN', 'Despejado', (40, 44), 2]
# [16, 'SALAMANCA', 'Despejado', (30, 34), 0]
# [16, 'LATINA', '', (60, 64), 0]
# [16, 'LATINA', '', (-1, -1), 0]
# [15, 'SALAMANCA', 'Despejado', (-1, -1), 0]
# [15, 'SALAMANCA', 'Despejado', (25, 29), 7]
# [14, 'USERA', 'Se desconoce', (30, 34), 1]
# [14, 'VICÁLVARO', 'Despejado', (21, 24), 0]
# [14, 'VICÁLVARO', 'Despejado', (50, 54), 0]
# [14, 'VICÁLVARO', 'Despejado', (50, 54), 0]
# [14, 'MORATALAZ', '', (45, 49), 0]
# [14, 'MORATALAZ', '', (-1, -1), 0]
# [14, 'MORATALAZ', '', (-1, -1), 0]
# [14, 'MORATALAZ', '', (-1, -1), 0]
# [13, 'CHAMARTÍN', '', (50, 54), 14]
# [13, 'CHAMARTÍN', '', (55, 59), 14]
# [12, 'CHAMBERÍ', '', (75, 100), 0]
# [12, 'USERA', 'Se desconoce', (21, 24), 7]
# [12, 'USERA', 'Se desconoce', (25, 29), 7]
# [12, 'RETIRO', 'Despejado', (40, 44), 0]
# [12, 'RETIRO', 'Despejado', (35, 39), 0]
# [12, 'RETIRO', 'Despejado', (30, 34), 0]
# [11, 'LATINA', 'Despejado', (55, 59), 14]
# [11, 'LATINA', 'Despejado', (75, 100), 3]
# [11, 'SALAMANCA', 'Despejado', (45, 49), 14]
# [11, 'SALAMANCA', 'Despejado', (75, 100), 3]
# [10, 'PUENTE DE VALLECAS', 'Despejado', (65, 69), 0]
# [10, 'PUENTE DE VALLECAS', 'Despejado', (60, 64), 0]
# [10, 'PUENTE DE VALLECAS', 'Despejado', (30, 34), 0]
# [9, 'VILLAVERDE', 'Despejado', (30, 34), 6]
# [9, 'VILLAVERDE', 'Despejado', (60, 64), 14]
# [8, 'FUENCARRAL-EL PARDO', '', (21, 24), 0]
# [8, 'FUENCARRAL-EL PARDO', '', (40, 44), 0]
# [8, 'FUENCARRAL-EL PARDO', '', (40, 44), 0]
# [7, 'USERA', '', (40, 44), 0]
# [7, 'USERA', '', (-1, -1), 0]
# [7, 'USERA', 'Despejado', (60, 64), 14]
# [6, 'VILLA DE VALLECAS', 'Lluvia débil', (-1, -1), 0]
# [6, 'VILLA DE VALLECAS', 'Lluvia débil', (-1, -1), 2]
# [6, 'VILLA DE VALLECAS', 'Lluvia débil', (45, 49), 5]
# [0, 'CHAMARTÍN', 'Despejado', (30, 34), 2]
# [23, 'FUENCARRAL-EL PARDO', 'Despejado', (21, 24), 7]
# [23, 'FUENCARRAL-EL PARDO', 'Despejado', (21, 24), 14]
# [23, 'FUENCARRAL-EL PARDO', '', (50, 54), 14]
# [23, 'FUENCARRAL-EL PARDO', '', (25, 29), 14]
# [22, 'SALAMANCA', 'Despejado', (65, 69), 0]
# [22, 'SALAMANCA', 'Despejado', (30, 34), 0]
# [22, 'LATINA', '', (50, 54), 0]
# [22, 'LATINA', '', (-1, -1), 0]
# [22, 'LATINA', '', (-1, -1), 0]
# [22, 'LATINA', '', (-1, -1), 0]
# [21, 'SAN BLAS-CANILLEJAS', 'Despejado', (45, 49), 2]
# [21, 'SAN BLAS-CANILLEJAS', 'Despejado', (40, 44), 2]
# [21, 'SAN BLAS-CANILLEJAS', 'Despejado', (25, 29), 2]
# [21, 'CIUDAD LINEAL', 'Despejado', (25, 29), 14]
# [21, 'CIUDAD LINEAL', 'Despejado', (60, 64), 5]
# [20, 'VILLA DE VALLECAS', 'Despejado', (18, 20), 14]
# [20, 'VILLA DE VALLECAS', 'Despejado', (35, 39), 5]
# [20, 'LATINA', '', (-1, -1), 0]
# [20, 'LATINA', '', (-1, -1), 0]
# [19, 'TETUÁN', 'Despejado', (65, 69), 14]
# [19, 'TETUÁN', 'Despejado', (30, 34), 2]
# [19, 'CIUDAD LINEAL', 'Despejado', (30, 34), 14]
# [19, 'CIUDAD LINEAL', 'Despejado', (40, 44), 14]
# [19, 'CIUDAD LINEAL', 'Despejado', (40, 44), 7]
# [19, 'CIUDAD LINEAL', 'Despejado', (65, 69), 14]
# [19, 'CIUDAD LINEAL', 'Despejado', (30, 34), 14]
# [19, 'CIUDAD LINEAL', 'Despejado', (25, 29), 14]
# [19, 'CHAMARTÍN', '', (50, 54), 0]
# [19, 'CHAMARTÍN', '', (30, 34), 0]
# [19, 'CHAMARTÍN', '', (35, 39), 0]
# [19, 'LATINA', 'Despejado', (25, 29), 7]
# [19, 'LATINA', 'Despejado', (45, 49), 7]
# [19, 'CENTRO', 'Despejado', (35, 39), 0]
# [19, 'CENTRO', 'Despejado', (30, 34), 0]
# [18, 'RETIRO', 'Despejado', (45, 49), 0]
# [18, 'RETIRO', 'Despejado', (75, 100), 0]
# [18, 'RETIRO', 'Despejado', (45, 49), 0]
# [18, 'MORATALAZ', 'Despejado', (21, 24), 7]
# [18, 'MORATALAZ', 'Despejado', (30, 34), 14]
# [18, 'MORATALAZ', 'Despejado', (35, 39), 14]
# [18, 'CIUDAD LINEAL', 'Despejado', (30, 34), 0]
# [18, 'CIUDAD LINEAL', 'Despejado', (60, 64), 0]
# [18, 'CIUDAD LINEAL', 'Despejado', (21, 24), 0]
# [18, 'CIUDAD LINEAL', 'Despejado', (18, 20), 0]
# [18, 'CIUDAD LINEAL', 'Despejado', (45, 49), 0]
# [18, 'CIUDAD LINEAL', 'Despejado', (10, 14), 0]
# [17, 'CHAMARTÍN', '', (45, 49), 0]
# [17, 'CHAMBERÍ', 'Despejado', (60, 64), 14]
# [17, 'CHAMBERÍ', 'Despejado', (45, 49), 14]
# [17, 'CHAMBERÍ', 'Despejado', (60, 64), 14]
# [16, 'RETIRO', 'Despejado', (21, 24), 0]
# [16, 'RETIRO', 'Despejado', (21, 24), 0]
# [16, 'RETIRO', 'Despejado', (50, 54), 0]
# [16, 'RETIRO', 'Despejado', (21, 24), 0]
# [16, 'SALAMANCA', 'Despejado', (21, 24), 14]
# [16, 'SALAMANCA', 'Despejado', (65, 69), 1]
# [15, 'ARGANZUELA', 'Despejado', (50, 54), 6]
# [14, 'SALAMANCA', 'Despejado', (30, 34), 14]
# [14, 'SALAMANCA', 'Despejado', (35, 39), 14]
# [14, 'CIUDAD LINEAL', 'Despejado', (55, 59), 0]
# [14, 'CIUDAD LINEAL', 'Despejado', (25, 29), 0]
# [14, 'USERA', '', (45, 49), 0]
# [14, 'USERA', '', (45, 49), 0]
# [14, 'USERA', '', (45, 49), 0]
# [13, 'CHAMARTÍN', 'Despejado', (75, 100), 1]
# [13, 'CHAMARTÍN', 'Despejado', (-1, -1), 0]
# [13, 'CIUDAD LINEAL', 'Despejado', (50, 54), 0]
# [13, 'CIUDAD LINEAL', 'Despejado', (25, 29), 0]
# [13, 'TETUÁN', 'Despejado', (35, 39), 0]
# [13, 'TETUÁN', 'Despejado', (25, 29), 0]
# [12, 'LATINA', 'Despejado', (25, 29), 0]
# [12, 'LATINA', 'Despejado', (55, 59), 0]
# [12, 'LATINA', 'Despejado', (65, 69), 0]
# [12, 'CENTRO', 'Despejado', (35, 39), 0]
# [12, 'CENTRO', 'Despejado', (35, 39), 14]
# [12, 'CENTRO', 'Despejado', (10, 14), 14]
# [12, 'CENTRO', 'Despejado', (40, 44), 0]
# [12, 'ARGANZUELA', 'Despejado', (50, 54), 2]
# [12, 'ARGANZUELA', 'Despejado', (75, 100), 3]
# [12, 'ARGANZUELA', 'Despejado', (60, 64), 14]
# [12, 'ARGANZUELA', 'Despejado', (35, 39), 1]
# [12, 'SALAMANCA', 'Despejado', (25, 29), 0]
# [9, 'CARABANCHEL', 'Despejado', (30, 34), 14]
# [9, 'CARABANCHEL', 'Despejado', (25, 29), 7]
# [9, 'CENTRO', 'Despejado', (35, 39), 0]
# [9, 'CENTRO', 'Despejado', (-1, -1), 0]
# [9, 'VILLAVERDE', 'Despejado', (30, 34), 14]
# [9, 'VILLAVERDE', 'Despejado', (21, 24), 7]
# [9, 'CARABANCHEL', 'Nublado', (40, 44), 7]
# [9, 'CARABANCHEL', 'Nublado', (21, 24), 14]
# [7, 'CIUDAD LINEAL', 'Despejado', (45, 49), 14]
# [7, 'CIUDAD LINEAL', 'Despejado', (30, 34), 7]
# [2, 'PUENTE DE VALLECAS', 'Despejado', (25, 29), 0]
# [2, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [0, 'FUENCARRAL-EL PARDO', 'Despejado', (-1, -1), 0]
# [0, 'FUENCARRAL-EL PARDO', 'Despejado', (-1, -1), 0]
# [23, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [23, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [23, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [23, 'CIUDAD LINEAL', 'Despejado', (25, 29), 0]
# [23, 'CIUDAD LINEAL', 'Despejado', (50, 54), 0]
# [23, 'CARABANCHEL', 'Despejado', (30, 34), 14]
# [23, 'CARABANCHEL', 'Despejado', (21, 24), 7]
# [23, 'CARABANCHEL', 'Despejado', (21, 24), 7]
# [23, 'CENTRO', 'Despejado', (15, 17), 2]
# [21, 'RETIRO', 'Despejado', (40, 44), 0]
# [21, 'RETIRO', 'Despejado', (45, 49), 0]
# [21, 'FUENCARRAL-EL PARDO', 'Despejado', (45, 49), 14]
# [21, 'FUENCARRAL-EL PARDO', 'Despejado', (30, 34), 1]
# [21, 'SAN BLAS-CANILLEJAS', 'Despejado', (18, 20), 7]
# [20, 'RETIRO', 'Despejado', (15, 17), 6]
# [20, 'CHAMBERÍ', 'Despejado', (55, 59), 14]
# [20, 'CHAMBERÍ', 'Despejado', (50, 54), 3]
# [19, 'BARAJAS', 'Despejado', (50, 54), 0]
# [19, 'BARAJAS', 'Despejado', (-1, -1), 0]
# [19, 'CHAMARTÍN', 'Despejado', (50, 54), 0]
# [19, 'SAN BLAS-CANILLEJAS', 'Despejado', (55, 59), 0]
# [19, 'SAN BLAS-CANILLEJAS', 'Despejado', (25, 29), 0]
# [19, 'SAN BLAS-CANILLEJAS', 'Despejado', (30, 34), 0]
# [18, 'RETIRO', 'Despejado', (30, 34), 14]
# [18, 'RETIRO', 'Despejado', (35, 39), 7]
# [18, 'RETIRO', 'Despejado', (30, 34), 14]
# [18, 'RETIRO', 'Despejado', (35, 39), 0]
# [18, 'RETIRO', 'Despejado', (35, 39), 14]
# [18, 'RETIRO', 'Despejado', (35, 39), 0]
# [18, 'SALAMANCA', 'Despejado', (55, 59), 14]
# [18, 'SALAMANCA', 'Despejado', (45, 49), 2]
# [18, 'SALAMANCA', 'Despejado', (35, 39), 2]
# [18, 'CARABANCHEL', 'Despejado', (30, 34), 0]
# [18, 'CARABANCHEL', 'Despejado', (-1, -1), 0]
# [17, 'MONCLOA-ARAVACA', 'Despejado', (21, 24), 14]
# [17, 'MONCLOA-ARAVACA', 'Despejado', (35, 39), 7]
# [16, 'CHAMARTÍN', 'Despejado', (40, 44), 0]
# [16, 'CHAMARTÍN', 'Despejado', (18, 20), 0]
# [16, 'CHAMARTÍN', 'Despejado', (35, 39), 0]
# [15, 'RETIRO', 'Despejado', (25, 29), 7]
# [15, 'RETIRO', 'Despejado', (55, 59), 7]
# [15, 'RETIRO', 'Despejado', (35, 39), 14]
# [15, 'VILLAVERDE', 'Despejado', (60, 64), 14]
# [15, 'VILLAVERDE', 'Despejado', (55, 59), 0]
# [15, 'RETIRO', '', (40, 44), 0]
# [15, 'RETIRO', '', (30, 34), 0]
# [15, 'PUENTE DE VALLECAS', 'Despejado', (60, 64), 0]
# [15, 'PUENTE DE VALLECAS', 'Despejado', (50, 54), 0]
# [15, 'BARAJAS', 'Despejado', (55, 59), 0]
# [15, 'BARAJAS', 'Despejado', (-1, -1), 0]
# [15, 'CENTRO', 'Despejado', (65, 69), 14]
# [15, 'CENTRO', 'Despejado', (40, 44), 0]
# [14, 'SALAMANCA', 'Despejado', (75, 100), 14]
# [14, 'SALAMANCA', 'Despejado', (45, 49), 7]
# [14, 'FUENCARRAL-EL PARDO', 'Despejado', (45, 49), 14]
# [14, 'FUENCARRAL-EL PARDO', 'Despejado', (45, 49), 0]
# [13, 'VILLAVERDE', '', (-1, -1), 0]
# [13, 'SALAMANCA', 'Despejado', (30, 34), 0]
# [13, 'SALAMANCA', 'Despejado', (45, 49), 0]
# [13, 'SALAMANCA', 'Despejado', (60, 64), 14]
# [13, 'SALAMANCA', 'Despejado', (21, 24), 14]
# [13, 'SALAMANCA', 'Despejado', (21, 24), 14]
# [13, 'USERA', 'Despejado', (40, 44), 14]
# [13, 'USERA', 'Despejado', (75, 100), 5]
# [13, 'USERA', 'Despejado', (75, 100), 5]
# [13, 'CHAMARTÍN', 'Despejado', (60, 64), 14]
# [13, 'CHAMARTÍN', 'Despejado', (25, 29), 7]
# [12, 'CHAMARTÍN', 'Despejado', (40, 44), 1]
# [12, 'CIUDAD LINEAL', 'Despejado', (30, 34), 0]
# [12, 'CIUDAD LINEAL', 'Despejado', (25, 29), 0]
# [12, 'TETUÁN', 'Despejado', (25, 29), 0]
# [12, 'TETUÁN', 'Despejado', (35, 39), 0]
# [12, 'ARGANZUELA', 'Despejado', (21, 24), 5]
# [10, 'BARAJAS', 'Despejado', (40, 44), 14]
# [10, 'BARAJAS', 'Despejado', (75, 100), 2]
# [10, 'VILLA DE VALLECAS', 'Despejado', (35, 39), 1]
# [10, 'VILLA DE VALLECAS', 'Despejado', (30, 34), 1]
# [10, 'VILLA DE VALLECAS', 'Despejado', (30, 34), 1]
# [10, 'VILLA DE VALLECAS', 'Despejado', (60, 64), 1]
# [10, 'VILLA DE VALLECAS', 'Despejado', (30, 34), 1]
# [10, 'VILLA DE VALLECAS', 'Despejado', (30, 34), 1]
# [10, 'CIUDAD LINEAL', 'Despejado', (45, 49), 14]
# [10, 'CIUDAD LINEAL', 'Despejado', (35, 39), 7]
# [7, 'CHAMBERÍ', 'Se desconoce', (-1, -1), 0]
# [7, 'CHAMBERÍ', 'Se desconoce', (-1, -1), 0]
# [6, 'SAN BLAS-CANILLEJAS', 'Despejado', (60, 64), 7]
# [6, 'SAN BLAS-CANILLEJAS', 'Despejado', (55, 59), 14]
# [2, 'HORTALEZA', 'Despejado', (-1, -1), 0]
# [2, 'CHAMARTÍN', '', (-1, -1), 0]
# [2, 'CHAMARTÍN', '', (-1, -1), 0]
# [0, 'TETUÁN', 'Despejado', (35, 39), 14]
# [0, 'TETUÁN', 'Despejado', (30, 34), 1]
# [0, 'CHAMBERÍ', 'Despejado', (35, 39), 0]
# [0, 'CHAMBERÍ', 'Despejado', (-1, -1), 0]
# [0, 'RETIRO', 'Despejado', (30, 34), 14]
# [0, 'RETIRO', 'Despejado', (30, 34), 7]
# [0, 'RETIRO', 'Despejado', (55, 59), 7]
# [0, 'CHAMARTÍN', 'Despejado', (25, 29), 14]
# [0, 'CHAMARTÍN', 'Despejado', (30, 34), 14]
# [0, 'CHAMARTÍN', 'Despejado', (35, 39), 7]
# [0, 'CHAMARTÍN', 'Despejado', (-1, -1), 0]
# [22, 'PUENTE DE VALLECAS', 'Despejado', (25, 29), 0]
# [22, 'PUENTE DE VALLECAS', 'Despejado', (65, 69), 14]
# [22, 'PUENTE DE VALLECAS', 'Despejado', (-1, -1), 0]
# [22, 'USERA', '', (25, 29), 0]
# [21, 'VICÁLVARO', 'Despejado', (50, 54), 14]
# [21, 'VICÁLVARO', 'Despejado', (30, 34), 14]
# [21, 'RETIRO', '', (45, 49), 0]
# [21, 'RETIRO', '', (50, 54), 0]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (35, 39), 0]
# [21, 'PUENTE DE VALLECAS', 'Despejado', (0, 5), 0]
# [21, 'HORTALEZA', 'Despejado', (25, 29), 14]
# [21, 'HORTALEZA', 'Despejado', (15, 17), 3]
# [21, 'RETIRO', 'Lluvia débil', (50, 54), 6]
# [21, 'RETIRO', 'Lluvia débil', (-1, -1), 0]
# [21, 'HORTALEZA', 'Lluvia débil', (21, 24), 0]
# [21, 'HORTALEZA', 'Lluvia débil', (35, 39), 0]
# [21, 'VILLAVERDE', '', (55, 59), 0]
# [21, 'VILLAVERDE', '', (35, 39), 0]
# [21, 'VILLAVERDE', '', (30, 34), 0]
# [21, 'CHAMBERÍ', 'Lluvia débil', (30, 34), 7]
# [20, 'SALAMANCA', 'Nublado', (-1, -1), 0]
# [20, 'SALAMANCA', 'Nublado', (35, 39), 14]
# [20, 'SALAMANCA', 'Nublado', (30, 34), 7]
# [20, 'SALAMANCA', 'Lluvia débil', (35, 39), 7]
# [20, 'SAN BLAS-CANILLEJAS', 'Nublado', (35, 39), 7]
# [20, 'SAN BLAS-CANILLEJAS', 'Nublado', (18, 20), 14]
# [20, 'SAN BLAS-CANILLEJAS', 'Nublado', (18, 20), 7]
# [20, 'SAN BLAS-CANILLEJAS', 'Nublado', (18, 20), 14]
# [20, 'SAN BLAS-CANILLEJAS', 'Nublado', (-1, -1), 0]
# [20, 'SAN BLAS-CANILLEJAS', 'Nublado', (-1, -1), 0]
# [20, 'SAN BLAS-CANILLEJAS', 'Nublado', (-1, -1), 0]
# [20, 'SAN BLAS-CANILLEJAS', 'Nublado', (-1, -1), 0]
# [20, 'SAN BLAS-CANILLEJAS', 'Nublado', (-1, -1), 0]
# [20, 'RETIRO', 'Nublado', (50, 54), 14]
# [20, 'RETIRO', 'Nublado', (15, 17), 6]
# [19, 'FUENCARRAL-EL PARDO', 'Lluvia débil', (30, 34), 14]
# [19, 'FUENCARRAL-EL PARDO', 'Lluvia débil', (15, 17), 6]
# [19, 'FUENCARRAL-EL PARDO', 'Lluvia débil', (15, 17), 7]
# [19, 'TETUÁN', 'Lluvia débil', (25, 29), 0]
# [19, 'TETUÁN', 'Lluvia débil', (50, 54), 0]
# [19, 'USERA', 'Despejado', (25, 29), 14]
# [19, 'USERA', 'Despejado', (18, 20), 7]
# [19, 'USERA', 'Despejado', (40, 44), 14]
# [19, 'USERA', 'Despejado', (40, 44), 14]
# [19, 'USERA', 'Despejado', (35, 39), 14]
# [19, 'USERA', 'Despejado', (6, 9), 7]
# [19, 'PUENTE DE VALLECAS', '', (30, 34), 0]
# [19, 'PUENTE DE VALLECAS', '', (21, 24), 0]
# [19, 'PUENTE DE VALLECAS', '', (21, 24), 0]
# [19, 'SALAMANCA', 'Nublado', (25, 29), 14]
# [19, 'SALAMANCA', 'Nublado', (25, 29), 14]
# [19, 'SALAMANCA', 'Nublado', (30, 34), 1]
# [19, 'HORTALEZA', 'Lluvia débil', (18, 20), 0]
# [19, 'HORTALEZA', 'Lluvia débil', (18, 20), 14]
# [19, 'HORTALEZA', 'Lluvia débil', (-1, -1), 0]
# [18, 'VILLAVERDE', 'Despejado', (25, 29), 0]
# [18, 'VILLAVERDE', 'Despejado', (40, 44), 0]
# [18, 'VILLAVERDE', 'Despejado', (21, 24), 0]
# [18, 'MORATALAZ', 'Lluvia débil', (18, 20), 7]
# [17, 'CARABANCHEL', 'Nublado', (18, 20), 1]
# [17, 'CARABANCHEL', 'Nublado', (18, 20), 14]
# [17, 'CARABANCHEL', 'Nublado', (-1, -1), 0]
# [17, 'CHAMBERÍ', 'Despejado', (25, 29), 14]
# [17, 'CHAMBERÍ', 'Despejado', (25, 29), 7]
# [17, 'RETIRO', 'Nublado', (-1, -1), 0]
# [17, 'LATINA', 'Nublado', (40, 44), 14]
# [17, 'LATINA', 'Nublado', (25, 29), 7]
# [17, 'HORTALEZA', 'Se desconoce', (55, 59), 14]
# [17, 'HORTALEZA', 'Se desconoce', (50, 54), 7]
# [17, 'LATINA', '', (30, 34), 0]
# [16, 'HORTALEZA', 'Lluvia débil', (18, 20), 2]
# [16, 'HORTALEZA', 'Lluvia débil', (21, 24), 14]
# [16, 'PUENTE DE VALLECAS', 'Lluvia débil', (55, 59), 14]
# [16, 'PUENTE DE VALLECAS', 'Lluvia débil', (45, 49), 7]
# [16, 'CHAMARTÍN', 'Lluvia débil', (35, 39), 7]
# [16, 'CHAMARTÍN', 'Lluvia débil', (45, 49), 14]
# [15, 'FUENCARRAL-EL PARDO', 'Despejado', (21, 24), 2]
# [15, 'FUENCARRAL-EL PARDO', 'Despejado', (-1, -1), 0]
# [15, 'VILLAVERDE', 'Nublado', (25, 29), 0]
# [15, 'VILLAVERDE', 'Nublado', (35, 39), 0]
# [15, 'VILLAVERDE', 'Nublado', (-1, -1), 0]
# [14, 'CHAMARTÍN', 'Se desconoce', (30, 34), 7]
# [14, 'CHAMARTÍN', 'Se desconoce', (25, 29), 7]
# [14, 'CHAMARTÍN', 'Se desconoce', (25, 29), 14]
# [14, 'CIUDAD LINEAL', 'Despejado', (21, 24), 7]
# [14, 'CIUDAD LINEAL', 'Despejado', (25, 29), 14]
# [14, 'CIUDAD LINEAL', 'Despejado', (50, 54), 14]
# [14, 'CHAMARTÍN', 'Despejado', (45, 49), 0]
# [14, 'CHAMARTÍN', 'Despejado', (60, 64), 0]
# [14, 'MORATALAZ', 'Despejado', (45, 49), 0]
# [14, 'MORATALAZ', 'Despejado', (21, 24), 0]
# [14, 'LATINA', 'Despejado', (35, 39), 14]
# [14, 'LATINA', 'Despejado', (35, 39), 7]
# [13, 'CHAMARTÍN', 'Despejado', (30, 34), 0]
# [13, 'CHAMARTÍN', 'Despejado', (-1, -1), 0]
# [13, 'CARABANCHEL', 'Despejado', (25, 29), 14]
# [13, 'CARABANCHEL', 'Despejado', (45, 49), 5]
# [13, 'FUENCARRAL-EL PARDO', '', (55, 59), 0]
# [13, 'FUENCARRAL-EL PARDO', '', (55, 59), 0]
# [12, 'VILLA DE VALLECAS', '', (50, 54), 0]
# [12, 'VILLA DE VALLECAS', '', (35, 39), 0]
# [12, 'MONCLOA-ARAVACA', 'Despejado', (35, 39), 0]
# [12, 'MONCLOA-ARAVACA', 'Despejado', (45, 49), 0]
# [11, 'CHAMBERÍ', 'Despejado', (35, 39), 14]
# [11, 'CHAMBERÍ', 'Despejado', (55, 59), 2]
# [11, 'ARGANZUELA', 'Despejado', (45, 49), 14]
# [11, 'ARGANZUELA', 'Despejado', (30, 34), 14]
# [10, 'CHAMARTÍN', 'Despejado', (-1, -1), 0]
# [10, 'CHAMARTÍN', 'Despejado', (-1, -1), 0]
# [9, 'CHAMARTÍN', 'Despejado', (25, 29), 7]
# [9, 'CHAMARTÍN', 'Despejado', (35, 39), 5]
# [2, 'SALAMANCA', 'Despejado', (21, 24), 7]
# [1, 'USERA', '', (35, 39), 0]
# [1, 'USERA', '', (21, 24), 0]
# [1, 'USERA', '', (25, 29), 0]
# [0, 'RETIRO', '', (25, 29), 0]
# [0, 'CHAMARTÍN', 'Despejado', (25, 29), 0]
# [0, 'CHAMARTÍN', 'Despejado', (35, 39), 0]
# [0, 'CHAMARTÍN', 'Despejado', (35, 39), 0]
# [0, 'CHAMARTÍN', 'Despejado', (35, 39), 0]
# [0, 'CHAMARTÍN', 'Despejado', (35, 39), 0]
# [0, 'CHAMARTÍN', 'Despejado', (35, 39), 0]

# %%
# Pruebas de funcionamiento:

for linea in datos_lista[0:4]:
    print(linea)
# Out:
# [23, 'RETIRO', 'Despejado', (25, 29), 0]
# [22, 'MONCLOA-ARAVACA', 'Despejado', (21, 24), 6]
# [20, 'FUENCARRAL-EL PARDO', 'Despejado', (45, 49), 14]
# [20, 'FUENCARRAL-EL PARDO', 'Despejado', (25, 29), 7]

# %% [markdown]
# ## c) Accidentalidad y mortalidad por edad [2 puntos]
#
# **c.1. Accidentalidad. Cómputo básico**
#
# Deseamos totalizar el número de accidentes de nuestra tabla por cada rango de edad. Para ello, te pido que uses un diccionario en el que la clave es el rango de edad y el valor, el total de accidentes para dicho rango de edad. Ahora, las posibilidades son dos:
#
# 1. Cada accidente actualiza el diccionario así: si ese rango de edad no está en el diccionario, se añade con un total de un accidente; si ya está, se añade una unidad más al tltal de accidentes de dicho rango de edad
#
# 2. Con un diccionario con el valor 0 por defecto.

# %%
# Esta celda debe ser completada por el estudiante
def totales(lista: list):
    diccionario = dict()

    for fila in lista:
        if fila[3] not in diccionario:
            diccionario[fila[3]] = 1
        else:
            diccionario[fila[3]] += 1
    return diccionario

# %%
# Prueba de funcionamiento:

total_accidentes_por_edades = totales(datos_lista)

for k, e in total_accidentes_por_edades.items():
    print(k, e)
# Out:
# (25, 29) 3437
# (21, 24) 2226
# (45, 49) 3084
# (-1, -1) 3962
# (55, 59) 2077
# (18, 20) 978
# (35, 39) 3332
# (40, 44) 3399
# (30, 34) 3362
# (50, 54) 2547
# (60, 64) 1272
# (65, 69) 641
# (15, 17) 250
# (70, 74) 427
# (75, 100) 657
# (0, 5) 289
# (6, 9) 175
# (10, 14) 305

# %% [markdown]
# **c.2. Accidentalidad con mortalidad**
#
# Deseamos recopilar, para cada rango de edad, el total de accidentes registrados en nuestra tabla, junto con el número de dichos accidentes que han resultado ser mortales. El cociente (multiplicado por mil) nos dará la tasa de accidentes mortales por cada mil accidentes.

# %%
# Esta celda debe ser completada por el estudiante
def totales_mortales(lista: list):
    diccionario = dict()
    mortales = [4] # solo hay 1 código para lesividad mortal

    for fila in lista:
        if fila[3] not in diccionario:
            valor = [1,0]
            if fila[4] in mortales:
                valor[1] = 1
            diccionario[fila[3]] = tuple(valor)
        else:
            valor = list(diccionario.get(fila[3]) )
            valor[0] += 1
            if fila[4] in mortales:
                valor[1] += 1
            diccionario[fila[3]] = tuple(valor)
    return diccionario.items()

# %% [markdown]
# Observa que la función `totales_mortales` devuelve una lista, y no un diccionario.

# %%
# Prueba de funcionamiento:

total_accidentes_y_muertes_por_edades = totales_mortales(datos_lista)

for edades, dos_totales in total_accidentes_y_muertes_por_edades:
    print(edades, dos_totales)
    
print()

# Total accidentes mortales / 1000 accidentes, por rangos de edad:

tasa_accidentes_mortales_por_mil = [(k, m*1000/n) for k, (n, m) in total_accidentes_y_muertes_por_edades]
                                    
for k_tasa  in tasa_accidentes_mortales_por_mil:
    print(k_tasa)
# Out:
# (25, 29) (3437, 3)
# (21, 24) (2226, 2)
# (45, 49) (3084, 4)
# (-1, -1) (3962, 0)
# (55, 59) (2077, 1)
# (18, 20) (978, 0)
# (35, 39) (3332, 8)
# (40, 44) (3399, 6)
# (30, 34) (3362, 2)
# (50, 54) (2547, 1)
# (60, 64) (1272, 1)
# (65, 69) (641, 1)
# (15, 17) (250, 0)
# (70, 74) (427, 1)
# (75, 100) (657, 4)
# (0, 5) (289, 1)
# (6, 9) (175, 0)
# (10, 14) (305, 0)
#
# ((25, 29), 0.8728542333430317)
# ((21, 24), 0.8984725965858041)
# ((45, 49), 1.297016861219196)
# ((-1, -1), 0.0)
# ((55, 59), 0.4814636494944632)
# ((18, 20), 0.0)
# ((35, 39), 2.4009603841536613)
# ((40, 44), 1.7652250661959399)
# ((30, 34), 0.594883997620464)
# ((50, 54), 0.39261876717707106)
# ((60, 64), 0.7861635220125787)
# ((65, 69), 1.5600624024960998)
# ((15, 17), 0.0)
# ((70, 74), 2.34192037470726)
# ((75, 100), 6.0882800608828)
# ((0, 5), 3.4602076124567476)
# ((6, 9), 0.0)
# ((10, 14), 0.0)

# %% [markdown]
# ## d) Algunas gráficas [1.5 puntos]
#
#
# **d.1 Un modelo de gráfica.** Vamos a diseñar un modelo de gráfica sencillo que nos sirva para las siguientes representaciones. Tomará como parámetro una lista de pares $(x, y)$, y opcionalmente los tres rótulos explicativos que necesitamos incluir. Además, queremos que las etiquetas de las abcisas aparezcan inclinadas, para poder luego mostrar intervalos de edad.
#
# Las pruebas de funcionamiento te darán más información que las explicaciones que pueda yo dar aquí.

# %%
# Esta celda debe ser completada por el estudiante
def representar_xxx_yyy(pares: list, rotulos=['','','']):
    transformar_str = [ tuple([str(elemento[0]),elemento[1]]) for elemento in pares]

    plt.plot(*zip(*transformar_str))
    plt.title(rotulos[0])
    plt.xlabel(rotulos[2])
    plt.ylabel(rotulos[1])
    plt.grid()
    plt.xticks(rotation=45)
    plt.show()

# %%
# Pruebas de funcionamiento:

representar_xxx_yyy([(1, 8), (2, 4), (3, 2), (4, 1), (5, 0.5), (6, 0.25)], ["Rótulo principal", "Ordenadas", "Abcisas"])

representar_xxx_yyy([(1, 1), (2, 2), (3, 4), (4, 8), (5, 16), (6, 32)])

# %% [markdown]
# **d.2. Tasas de muerte por edades**
#
# Queremos aplicar nuestro modelo de gráfica a la representación de las tasas de accidentes mortales por edad, que hemos calculado un poco antes. Pero obtenemos una gráfica poco adecuada, porque las edades (las abcisas) están en un orden arbitrario.

# %%
# Intento de representación:

rotulos = "Tasas de muerte en accidentes por rangos de edad", "Tasas de muerte", "Rangos de edad"
representar_xxx_yyy(tasa_accidentes_mortales_por_mil, rotulos)

# %% [markdown]
# Para remediar esto se ha de reordenar la lista de pares absisa-ordenada, atendiendo a las abcisas. También, el elemento de abcisa (-1, -1) se ha de suprimir. Esto es lo que te pido.

# %%
# Esta celda debe ser completada por el estudiante
tasa_accidentes_mortales_por_mil = sorted(tasa_accidentes_mortales_por_mil, key=lambda x: x[0])
tasa_accidentes_mortales_por_mil.pop(0)
tasa_accidentes_mortales_por_mil
# Out:
# [((0, 5), 3.4602076124567476),
#  ((6, 9), 0.0),
#  ((10, 14), 0.0),
#  ((15, 17), 0.0),
#  ((18, 20), 0.0),
#  ((21, 24), 0.8984725965858041),
#  ((25, 29), 0.8728542333430317),
#  ((30, 34), 0.594883997620464),
#  ((35, 39), 2.4009603841536613),
#  ((40, 44), 1.7652250661959399),
#  ((45, 49), 1.297016861219196),
#  ((50, 54), 0.39261876717707106),
#  ((55, 59), 0.4814636494944632),
#  ((60, 64), 0.7861635220125787),
#  ((65, 69), 1.5600624024960998),
#  ((70, 74), 2.34192037470726),
#  ((75, 100), 6.0882800608828)]

# %%
# Prueba de funcionamiento:

representar_xxx_yyy(tasa_accidentes_mortales_por_mil, rotulos)

# %% [markdown]
# **d.3. Tasas de muerte por rangos horarios**
#
# De forma similar a lo resuelto en los apartados anteriores, deseamos preparar los datos y un gráfico con la tasa de muerte por rangos horarios. En lugar de tratar los rangos por horas enteras (las 4 representa el intervalo entre las 4:00 y las 4:59), deseamos representar de dos en dos horas (las 4 representa el intervalo entre las 4:00 y las 5:59, las 6, entre las 6:00 y las 7:59, etc.)
#
# Observa que se necesitan dos funciones, una para recopilar los datos, calcular las tasas, dar  una lista ordenada, etc., y otra para preparar las abcisas, cadenas de caracteres con las horas de dos en dos, junto con sus tasas respectivas.

# %%
# Esta celda debe ser completada por el estudiante

# %%
# Prueba de funcionamiento:

tasas_accidentes_y_muertes_por_horario = totales_mortales_por_horario(datos_lista)

print(tasas_accidentes_y_muertes_por_horario)

print()

datos_para_grafica = emparejar_abcisas(tasas_accidentes_y_muertes_por_horario)

print(datos_para_grafica)

rotulos = "Tasas de muerte en accidentes por rangos horarios", "Tasas de muerte", "Rangos horarios"
representar_xxx_yyy(datos_para_grafica, rotulos)
# Out:
# [(0, 1.9230769230769231), (2, 4.178272980501393), (4, 1.949317738791423), (6, 0.8635578583765112), (8, 1.1415525114155252), (10, 1.5337423312883436), (12, 0.8234971177600878), (14, 1.112099644128114), (16, 0.5351886540005352), (18, 0.4287245444801715), (20, 1.1999040076793857), (22, 1.187178472497032)]
#
# [('(0, 2)', 1.9230769230769231), ('(2, 4)', 4.178272980501393), ('(4, 6)', 1.949317738791423), ('(6, 8)', 0.8635578583765112), ('(8, 10)', 1.1415525114155252), ('(10, 12)', 1.5337423312883436), ('(12, 14)', 0.8234971177600878), ('(14, 16)', 1.112099644128114), ('(16, 18)', 0.5351886540005352), ('(18, 20)', 0.4287245444801715), ('(20, 22)', 1.1999040076793857), ('(22, 24)', 1.187178472497032)]

# %% [markdown]
# ## e) Operaciones con dataframes [1.5 puntos]
#
# En este apartado, vamos a trabajar con tablas de la librería `pandas`, llamadas `dataframes`.
#
# **e1. Carga del dataframe.**
# La primera operación que necesitamos es cargar el archivo de datos en una tabla, como se ve en el siguiente ejemplo.

# %%
# Esta celda debe ser completada por el estudiante
def cargar_dataframe_v0(fichero: str):
    df = pd.read_csv(fichero, encoding='iso-8859-1', sep=';', usecols=['HORA','DISTRITO','RANGO DE EDAD','LESIVIDAD*'])
    return df

# %%
tabla_pre = cargar_dataframe_v0("2020_Accidentalidad.csv")
print(tabla_pre)
# Out:
#         HORA             DISTRITO    RANGO DE EDAD  LESIVIDAD*
# 0      23:15               RETIRO  DE 25 A 29 AÑOS         NaN
# 1      22:35      MONCLOA-ARAVACA  DE 21 A 24 AÑOS         6.0
# 2      20:15  FUENCARRAL-EL PARDO  DE 45 A 49 AÑOS        14.0
# 3      20:15  FUENCARRAL-EL PARDO  DE 25 A 29 AÑOS         7.0
# 4      19:45               CENTRO      DESCONOCIDA         NaN
# ...      ...                  ...              ...         ...
# 32415   0:18            CHAMARTÍN  DE 35 A 39 AÑOS         NaN
# 32416   0:18            CHAMARTÍN  DE 35 A 39 AÑOS         NaN
# 32417   0:18            CHAMARTÍN  DE 35 A 39 AÑOS         NaN
# 32418   0:18            CHAMARTÍN  DE 35 A 39 AÑOS         NaN
# 32419   0:18            CHAMARTÍN  DE 35 A 39 AÑOS         NaN
#
# [32420 rows x 4 columns]

# %% [markdown]
# **e2. Carga del dataframe, codificando rangos de edad y lesividad.**
# Ahora, queremos modificar esta lectura para que los rangos de edad se conviertan en el intervalo correspondiente. Además, vemos que el nivel de lesividad se ha leído directamente como un real, y las cadenas en blanco se han traducido a `NaN` (*Not a Number*). Queremos ponerlo como un entero, consistente en un 1 cuando hay lesividad. Cuando no se conoce la lesividad, o no hay lesividad (casos codificados con un 0, un 77, un 14), anotamos un 0 en la tabla.

# %%
# Esta celda debe ser completada por el estudiante
def cargar_dataframe(fichero: str):
    df = cargar_dataframe_v0(fichero)

    # quitamos los NaN
    df['LESIVIDAD*'] = df['LESIVIDAD*'] .fillna(0)

    # aplico funciones
    df['HORA'] = df['HORA'].apply(redondeo_hora)
    df['RANGO DE EDAD'] = df['RANGO DE EDAD'].apply(rango_edad)
    df['LESIVIDAD*'] = df['LESIVIDAD*'].apply(lambda x: 0 if x in [0,77,14] else 1)

    return df

# %%
tabla = cargar_dataframe("2020_Accidentalidad.csv")
tabla
# Out:
#        HORA             DISTRITO RANGO DE EDAD  LESIVIDAD*
# 0        23               RETIRO      (25, 29)           0
# 1        22      MONCLOA-ARAVACA      (21, 24)           1
# 2        20  FUENCARRAL-EL PARDO      (45, 49)           0
# 3        20  FUENCARRAL-EL PARDO      (25, 29)           1
# 4        19               CENTRO      (-1, -1)           0
# ...     ...                  ...           ...         ...
# 32415     0            CHAMARTÍN      (35, 39)           0
# 32416     0            CHAMARTÍN      (35, 39)           0
# 32417     0            CHAMARTÍN      (35, 39)           0
# 32418     0            CHAMARTÍN      (35, 39)           0
# 32419     0            CHAMARTÍN      (35, 39)           0
#
# [32420 rows x 4 columns]

# %% [markdown]
# **e3. Tabla de número de accidentes por rangos de edad**
#
# Nos interesa quedarnos únicamente con dos columnas: el rango de edad y el número de accidentes, formando una tabla nueva. Esta tabla debe mostrarse en orden ascendente de rango de edad.

# %%
# Esta celda debe ser completada por el estudiante
# el sort por defecto es True
num_accidentes = tabla.groupby(['RANGO DE EDAD']).size().reset_index(name='NumAccs').rename(columns={'RANGO DE EDAD':'Edad'})
num_accidentes
# Out:
#          Edad  NumAccs
# 0    (-1, -1)     3962
# 1      (0, 5)      289
# 2      (6, 9)      175
# 3    (10, 14)      305
# 4    (15, 17)      250
# 5    (18, 20)      978
# 6    (21, 24)     2226
# 7    (25, 29)     3437
# 8    (30, 34)     3362
# 9    (35, 39)     3332
# 10   (40, 44)     3399
# 11   (45, 49)     3084
# 12   (50, 54)     2547
# 13   (55, 59)     2077
# 14   (60, 64)     1272
# 15   (65, 69)      641
# 16   (70, 74)      427
# 17  (75, 100)      657

# %% [markdown]
# Esta tabla contiene el rango de edad $(-1, -1)$, que no nos interesa. Por eso preferimos descartar esta fila.

# %%
# Esta celda debe ser completada por el estudiante
num_accidentes_valid = num_accidentes.drop(0)
num_accidentes_valid
# Out:
#          Edad  NumAccs
# 1      (0, 5)      289
# 2      (6, 9)      175
# 3    (10, 14)      305
# 4    (15, 17)      250
# 5    (18, 20)      978
# 6    (21, 24)     2226
# 7    (25, 29)     3437
# 8    (30, 34)     3362
# 9    (35, 39)     3332
# 10   (40, 44)     3399
# 11   (45, 49)     3084
# 12   (50, 54)     2547
# 13   (55, 59)     2077
# 14   (60, 64)     1272
# 15   (65, 69)      641
# 16   (70, 74)      427
# 17  (75, 100)      657

# %% [markdown]
# **e4. Accidentes con consecuencias médicas.**
#
# Queremos totalizar ahora los accidentes que requieren algún tipo de atención sanitaria o con resultado de muerte por cada rango de edad.

# %%
# Esta celda debe ser completada por el estudiante
accidentes_medicos = tabla[tabla['LESIVIDAD*'] > 0].groupby(['RANGO DE EDAD']).size().reset_index(name='NumAccsConLesiones').rename(columns={'RANGO DE EDAD':'Edad'}).drop(0)
accidentes_medicos
# Out:
#          Edad  NumAccsConLesiones
# 1      (0, 5)                 107
# 2      (6, 9)                  73
# 3    (10, 14)                 135
# 4    (15, 17)                 114
# 5    (18, 20)                 325
# 6    (21, 24)                 720
# 7    (25, 29)                1184
# 8    (30, 34)                1098
# 9    (35, 39)                 944
# 10   (40, 44)                 899
# 11   (45, 49)                 735
# 12   (50, 54)                 587
# 13   (55, 59)                 493
# 14   (60, 64)                 281
# 15   (65, 69)                 153
# 16   (70, 74)                 129
# 17  (75, 100)                 260

# %% [markdown]
# **e5. Unión de dos tablas.**
#
# Deseamos ahora combinar las dos tablas generadas, usando la columna "Edad" como pivote, al estilo de la operación `inner join` de SQL en el mundo de las bases de datos.

# %%
# Esta celda debe ser completada por el estudiante
# how es inner por defecto
union_tablas = pd.merge(num_accidentes_valid, accidentes_medicos,on='Edad')
union_tablas
# Out:
#          Edad  NumAccs  NumAccsConLesiones
# 0      (0, 5)      289                 107
# 1      (6, 9)      175                  73
# 2    (10, 14)      305                 135
# 3    (15, 17)      250                 114
# 4    (18, 20)      978                 325
# 5    (21, 24)     2226                 720
# 6    (25, 29)     3437                1184
# 7    (30, 34)     3362                1098
# 8    (35, 39)     3332                 944
# 9    (40, 44)     3399                 899
# 10   (45, 49)     3084                 735
# 11   (50, 54)     2547                 587
# 12   (55, 59)     2077                 493
# 13   (60, 64)     1272                 281
# 14   (65, 69)      641                 153
# 15   (70, 74)      427                 129
# 16  (75, 100)      657                 260

# %% [markdown]
# **e6. Proporción de accidentes con lesiones.**
#
# Deseamos ahora ver las cifras de lesiones en términos relativos, esto es, como el porcentaje  proporcióde accidentes en que se producen lesiones.

# %%
# Esta celda debe ser completada por el estudiante
proporcion =  pd.DataFrame({'PropLesiones':accidentes_medicos['NumAccsConLesiones'] * 100 / num_accidentes_valid['NumAccs']}).reset_index(drop=True)
prop_lesiones = pd.concat([union_tablas,proporcion], axis=1)
prop_lesiones
# Out:
#          Edad  NumAccs  NumAccsConLesiones  PropLesiones
# 0      (0, 5)      289                 107     37.024221
# 1      (6, 9)      175                  73     41.714286
# 2    (10, 14)      305                 135     44.262295
# 3    (15, 17)      250                 114     45.600000
# 4    (18, 20)      978                 325     33.231084
# 5    (21, 24)     2226                 720     32.345013
# 6    (25, 29)     3437                1184     34.448647
# 7    (30, 34)     3362                1098     32.659131
# 8    (35, 39)     3332                 944     28.331333
# 9    (40, 44)     3399                 899     26.448956
# 10   (45, 49)     3084                 735     23.832685
# 11   (50, 54)     2547                 587     23.046722
# 12   (55, 59)     2077                 493     23.736158
# 13   (60, 64)     1272                 281     22.091195
# 14   (65, 69)      641                 153     23.868955
# 15   (70, 74)      427                 129     30.210773
# 16  (75, 100)      657                 260     39.573820

# %% [markdown]
# **e6. Gráfico.**
#
# Finalmente, deseamos presentar la proporción de accidentes con lesiones por edades, por si al ver esto pudiéramos extraer alguna conclusión útil.

# %%
# Esta celda debe ser completada por el estudiante
df_grafica = pd.DataFrame({'Edad':prop_lesiones['Edad'].values.tolist(), 'PropLesiones':prop_lesiones['PropLesiones'].values.tolist()})
ax = df_grafica.plot.bar(x='Edad', y='PropLesiones')

# %% [markdown]
# ## f) Un cálculo masivo con map-reduce [0.5 puntos]
#
# En este apartado se ha de realizar un programa aparte que calcule, para cada rango de edad, un par de enteros con los totales de podría activarse así desde la consola:
#
#     C:\...> python total_accs_edad.py -q 2020_Accidentalidad.csv
#
# El programa funcionará necesariamente con la técnica map-reduce, que podemos poner en juego con la librería `mrjob`.
#
# El funcionamiento del mismo se puede activar también desde aquí:

# %%
# Hagamos una llamada al programa de consola desde aquí:

! python total_accs_edad.py -q 2020_Accidentalidad.csv

# %%
# Para que el resultado se almacene en un archivo:

! python total_accs_edad.py -q 2020_Accidentalidad.csv  > accidentalidad_y_mortalidad_por_edades.txt

# %% [markdown]
# Para que pueda yo ver tu programa cómodamente desde aquí, también se puede mostrar con un comando de la consola, anteponiendo el símbolo `!`. Observaciones:
#
# - La instrucción siguiente está comentada para ocultar una solución mía.
#   Tú debes suprimir el símbolo `#` del comentario
#   para mostrar tu solución aquí.
# - Desde mac o linux, se ha de usar el comando `cat`, en vez de `type`.

# %%
! type total_accs_edad.py

# %% [markdown]
# ## g) Un apartado libre [0.5 puntos]
#
# Dejo este apartado a tu voluntad. Inventa tú mismo el enunciado y resuélvelo, mostrando algún aspecto de programación en Python no contemplado o alguna técnica o librería que no has puesto en juego en los apartados anteriores, relacionado con el análisis de datos y con este proyecto. He aquí dos ejemplos posibles:
#
# - Me he quedado un poco insatisfecho con el uso de pandas, un poco escaso: este apartado adicional podría usar dicha librería poniendo en juego algunas operaciones que no hemos visto.
#
# - Tampoco me gusta mucho el acabado de las figuras:
#   la librería Plotly puede ser quizá permitirte trazar figuras más
#   profesionales, y una posibilidad sencilla es quizá
#   importar los datos del archivo creado por el programa de map-reduce
#   y representarlos gráficamente.
#
# Estos ejemplos pueden servirte como pista, pero que no te limiten. Hay muchas otras posibilidades: geopandas, web scraping, etc.
#
# En la evaluación, si este apartado está bien o muy bien, anota un 0.4. El 0,5 lo reservaremos para las situaciones en que se presente algo brillante, con alguna idea original o alguna técnica novedosa o complejidad especial o algún gráfico vistoso. Especialmente quien opta a un 9,5 o más, debe esmerarse en plantear este apartado a la altura de esa calificación.

# %%
# Este apartado debe ser completado por el estudiante

# %%
# Pruebas de funcionamiento:

# %% [markdown]
# ### Datos personales
#
# <br>
#
# <font color="darkblue">
#
# -   **Apellidos:** Vásquez Peraza
# -   **Nombre:** Óscar David
# -   **Email:** odvperaza@ucm.es
# -   **Fecha:** 25/04/2022
#
# <br>
#
# <font color="black">
#
# ### Ficha de autoevaluación
#
# <br>
#
# <font color="darkblue">
#
# <font color="green">
# **Comentarios sobre la autoevaluación**:
#
# Aquí vienen comentarios del estudiante. Lo siguiente es un ejemplo posible obviamente ... elimina este párrafo y redacta el tuyo propio, en azul.
#
# <font color="darkblue">
#
# |Apartado|Calificación|Comentario|
# |-|-|-|
# |a)  |2.0  / 2.0  |Completamente resuelto |
# |b)  |0.0  / 2.0  |No lo he conseguido |
# |c)  |0.25 / 2.0  |Sólo he conseguido una parte mínima |
# |d)  |0.25 / 1.5  |Sólo he conseguido una parte mínima |
# |e)  |0.0  / 1.5  |No lo he conseguido |
# |f)  |0.5  / 0.5  |No lo he conseguido |
# |g)  |0.0  / 0.5  |No he logrado el correcto funcionamiento |
# |**Total** |**2.5** / 10.0|**Suspenso**|
#
# </font>
#
# <font color="black">
#
# ### Ayuda recibida y fuentes utilizadas
#
# <br>
#
# <font color="green">
# ... comentarios del estudiante ...
# Pon tú este párrafo con tus propias observaciones. Elimina este párrafo en verde.
# </font>
#
# <br>
#
# <font color="black">
#
# ### Comentario adicional
#
# <br>
#
# <font color="green">
# ... Este apartado es optativo. Si lo completas, ponlo en azul; si no, suprímelo con su título.
#
# <br>

# %%
# Esta celda se ha de respetar: está aquí para comprobar el funcionamiento de algunas funciones por parte de tu profesor
